# %%
# import sys
# sys.path.append('/home/briedle/web-projects/finance')


# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'stock_visualizer_backend.settings')
# import environ

# env = environ.Env()
# # Reading .env file
# environ.Env.read_env()

# from django.conf import settings
# settings.configure(
#     DATABASES = {
#         'default': {
#             'ENGINE': 'django.db.backends.postgresql',
#             'NAME': 'financial',
#             'USER': 'briedle',
#             'PASSWORD': 'ben21788',
#             'HOST': 'localhost',  # Or your PostgreSQL server address
#             'PORT': '5432',
#         }
#     },
#     INSTALLED_APPS = [
#         'django.contrib.admin',
#         'django.contrib.auth',
#         'django.contrib.contenttypes',
#         'django.contrib.sessions',
#         'django.contrib.messages',
#         'django.contrib.staticfiles',
#         'corsheaders',
#         'stocks',
#         'storages',
#     ]
# )




import requests
import pandas as pd
import numpy as np
import copy
import importlib
import os
import json
from IPython.display import display, JSON
import sqlalchemy
import pandas as pd
import datetime
# import yfinance as yf
# import pandas_datareader as pdr
import bs4 as bs
import psycopg2

# pyjsonviewer.view_data(json_data=response.json())
# import tkinter as tk
# import pyjsonviewer
# from pandas import json_normalize
# from flatten_json import flatten
import parse_alpha_vantage as pav


importlib.reload(pav)
print(os.getenv("RAPIDAPI_KEY"))
# Out:
# /home/briedle/web-projects/finance/stock_visualizer_backend
# None

# %%
import os
import django

# Set up Django environment
os.chdir('/home/briedle/web-projects/finance/stock_visualizer_backend')

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'stock_visualizer_backend.settings')
django.setup()

# %%
db_name='financial'
db_user='briedle'
db_password = 'ben21788'
db_host = 'localhost'
db_port = '5432'

# %%
try:
    con = psycopg2.connect(
        dbname=db_name,
        user=db_user,
        password=db_password,
        host=db_host,  # or your server IP
        port=db_port,  # default PostgreSQL port
    )
except psycopg2.Error as e:
    print("Unable to connect to the database")
    print(e)
    
cursor = con.cursor()

# %%
top_companies = [
    "AAPL",  # Apple Inc.
    "MSFT",  # Microsoft Corporation
    "AMZN",  # Amazon.com Inc.
    "GOOGL",  # Alphabet Inc. (Google)
    "GOOG",  # Alphabet Inc. (Google)
    "META",  # Meta Platforms, Inc. (Facebook)
    "TSLA",  # Tesla, Inc.
    "BRK.A",  # Berkshire Hathaway Inc.
    "BRK.B",  # Berkshire Hathaway Inc.
    "NVDA",  # NVIDIA Corporation
    "JPM",  # JPMorgan Chase & Co.
    "JNJ",  # Johnson & Johnson
    "V",  # Visa Inc.
    "PG",  # Procter & Gamble Company
    "UNH",  # UnitedHealth Group Incorporated
    "MA",  # Mastercard Incorporated
    "PYPL",  # PayPal Holdings, Inc.
    "DIS",  # The Walt Disney Company
    "BABA",  # Alibaba Group Holding Limited
    "HD",  # The Home Depot, Inc.
    "CMCSA",  # Comcast Corporation
    "BAC",  # Bank of America Corporation
    "INTC",  # Intel Corporation
    "T",  # AT&T Inc.
    "KO",  # The Coca-Cola Company
    "WMT",  # Walmart Inc.
    "NFLX",  # Netflix, Inc.
    "PFE",  # Pfizer Inc.
    "ADBE",  # Adobe Inc.
    "CRM",  # salesforce.com, inc.
    "NKE",  # NIKE, Inc.
    "XOM",  # Exxon Mobil Corporation
    "MRK",  # Merck & Co., Inc.
    "CSCO",  # Cisco Systems, Inc.
    "ABT",  # Abbott Laboratories
    "TMO",  # Thermo Fisher Scientific Inc.
    "VZ",  # Verizon Communications Inc.
    "PEP",  # PepsiCo, Inc.
    "ORCL",  # Oracle Corporation
    "NVS",  # Novartis AG
    "ABBV",  # AbbVie Inc.
    "DHR",  # Danaher Corporation
    "BMY",  # Bristol Myers Squibb Co.
    "PM",  # Philip Morris International Inc.
    "LLY",  # Eli Lilly and Company
    "AVGO",  # Broadcom Inc.
    "GE",  # General Electric Company
    "CVX",  # Chevron Corporation
    "ABB",  # ABB Ltd.
    "DOW",  # Dow Inc.
]

# %%
api_key = "1c63ffa51amsh98ddb79fb2729e8p14b4fajsn657b83e58886"

# %%
parsed_data = []

# %%
# top_companies[:5]


top_companies_copy = copy.deepcopy(top_companies)
for company in top_companies:
    try:
        data = parse_alpha_vantage.fetch_data(company, api_key=api_key)
        print(f"{company} data fetch succeeded")
        parsed_data.append(parse_alpha_vantage.parse_monthly_adjusted(data))
        print(f"{company} data parsing and appending succeeded")
        top_companies_copy.remove(company)
        print(f"{company} done and removed from list")
    except KeyError:
        print(f"{company} had problem")

top_companies = copy.deepcopy(top_companies_copy)

# %%
# company_prices = pd.concat(parsed_data)
# company_prices = company_prices.drop_duplicates(['symbol', 'date'])
# company_prices.to_csv('data/monthly_top50_company_prices.csv', index=False)
# company_prices

# %%
t = parse_alpha_vantage.fetch_data(
    top_companies[0],
    function="INCOME_STATEMENT",
    api_key=api_key,
)
t
# Out:
# {'symbol': 'AAPL',
#  'annualReports': [{'fiscalDateEnding': '2023-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '169148000000',
#    'totalRevenue': '379352000000',
#    'costOfRevenue': '239069000000',
#    'costofGoodsAndServicesSold': '214137000000',
#    'operatingIncome': '114301000000',
#    'sellingGeneralAndAdministrative': '24932000000',
#    'researchAndDevelopment': '29915000000',
#    'operatingExpenses': '54847000000',
#    'investmentIncomeNet': '3750000000',
#    'netInterestIncome': '-3933000000',
#    'interestIncome': '183000000',
#    'interestExpense': '3933000000',
#    'nonInterestIncome': '383285000000',
#    'otherNonOperatingIncome': '-382000000',
#    'depreciation': '8500000000',
#    'depreciationAndAmortization': '11519000000',
#    'incomeBeforeTax': '113736000000',
#    'incomeTaxExpense': '16741000000',
#    'interestAndDebtExpense': '3933000000',
#    'netIncomeFromContinuingOperations': '96995000000',
#    'comprehensiveIncomeNetOfTax': '96652000000',
#    'ebit': '117669000000',
#    'ebitda': '125820000000',
#    'netIncome': '96995000000'},
#   {'fiscalDateEnding': '2022-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '170782000000',
#    'totalRevenue': '391397000000',
#    'costOfRevenue': '248640000000',
#    'costofGoodsAndServicesSold': '223546000000',
#    'operatingIncome': '119437000000',
#    'sellingGeneralAndAdministrative': '25094000000',
#    'researchAndDevelopment': '26251000000',
#    'operatingExpenses': '51345000000',
#    'investmentIncomeNet': '2825000000',
#    'netInterestIncome': '-2931000000',
#    'interestIncome': '106000000',
#    'interestExpense': '2931000000',
#    'nonInterestIncome': '394328000000',
#    'otherNonOperatingIncome': '-228000000',
#    'depreciation': '8700000000',
#    'depreciationAndAmortization': '11104000000',
#    'incomeBeforeTax': '119103000000',
#    'incomeTaxExpense': '19300000000',
#    'interestAndDebtExpense': '2931000000',
#    'netIncomeFromContinuingOperations': '99803000000',
#    'comprehensiveIncomeNetOfTax': '88531000000',
#    'ebit': '122034000000',
#    'ebitda': '130541000000',
#    'netIncome': '99803000000'},
#   {'fiscalDateEnding': '2021-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '152836000000',
#    'totalRevenue': '363172000000',
#    'costOfRevenue': '234954000000',
#    'costofGoodsAndServicesSold': '212981000000',
#    'operatingIncome': '108949000000',
#    'sellingGeneralAndAdministrative': '21973000000',
#    'researchAndDevelopment': '21914000000',
#    'operatingExpenses': '43887000000',
#    'investmentIncomeNet': '2843000000',
#    'netInterestIncome': '-2645000000',
#    'interestIncome': '2843000000',
#    'interestExpense': '2645000000',
#    'nonInterestIncome': '365817000000',
#    'otherNonOperatingIncome': '60000000',
#    'depreciation': '9500000000',
#    'depreciationAndAmortization': '11284000000',
#    'incomeBeforeTax': '109207000000',
#    'incomeTaxExpense': '14527000000',
#    'interestAndDebtExpense': '2645000000',
#    'netIncomeFromContinuingOperations': '94680000000',
#    'comprehensiveIncomeNetOfTax': '95249000000',
#    'ebit': '111852000000',
#    'ebitda': '120233000000',
#    'netIncome': '94680000000'},
#   {'fiscalDateEnding': '2020-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '104956000000',
#    'totalRevenue': '271642000000',
#    'costOfRevenue': '189475000000',
#    'costofGoodsAndServicesSold': '169559000000',
#    'operatingIncome': '66288000000',
#    'sellingGeneralAndAdministrative': '19916000000',
#    'researchAndDevelopment': '18752000000',
#    'operatingExpenses': '38668000000',
#    'investmentIncomeNet': '3763000000',
#    'netInterestIncome': '-2873000000',
#    'interestIncome': '3763000000',
#    'interestExpense': '2873000000',
#    'nonInterestIncome': '274515000000',
#    'otherNonOperatingIncome': '-87000000',
#    'depreciation': '9700000000',
#    'depreciationAndAmortization': '11056000000',
#    'incomeBeforeTax': '67091000000',
#    'incomeTaxExpense': '9680000000',
#    'interestAndDebtExpense': '2873000000',
#    'netIncomeFromContinuingOperations': '57411000000',
#    'comprehensiveIncomeNetOfTax': '57453000000',
#    'ebit': '69964000000',
#    'ebitda': '77344000000',
#    'netIncome': '57411000000'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '98392000000',
#    'totalRevenue': '256598000000',
#    'costOfRevenue': '180027000000',
#    'costofGoodsAndServicesSold': '161782000000',
#    'operatingIncome': '63930000000',
#    'sellingGeneralAndAdministrative': '18245000000',
#    'researchAndDevelopment': '16217000000',
#    'operatingExpenses': '34462000000',
#    'investmentIncomeNet': '4961000000',
#    'netInterestIncome': '-3576000000',
#    'interestIncome': '4961000000',
#    'interestExpense': '3576000000',
#    'nonInterestIncome': '260174000000',
#    'otherNonOperatingIncome': '422000000',
#    'depreciation': '11300000000',
#    'depreciationAndAmortization': '12547000000',
#    'incomeBeforeTax': '65737000000',
#    'incomeTaxExpense': '10481000000',
#    'interestAndDebtExpense': '3576000000',
#    'netIncomeFromContinuingOperations': '55256000000',
#    'comprehensiveIncomeNetOfTax': '58037000000',
#    'ebit': '69313000000',
#    'ebitda': '76477000000',
#    'netIncome': '55256000000'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '101839000000',
#    'totalRevenue': '265595000000',
#    'costOfRevenue': '163756000000',
#    'costofGoodsAndServicesSold': '163756000000',
#    'operatingIncome': '70898000000',
#    'sellingGeneralAndAdministrative': '16705000000',
#    'researchAndDevelopment': '14236000000',
#    'operatingExpenses': '30941000000',
#    'investmentIncomeNet': '5686000000',
#    'netInterestIncome': '-3240000000',
#    'interestIncome': '5686000000',
#    'interestExpense': '3240000000',
#    'nonInterestIncome': '265595000000',
#    'otherNonOperatingIncome': '-441000000',
#    'depreciation': '9300000000',
#    'depreciationAndAmortization': '10903000000',
#    'incomeBeforeTax': '72903000000',
#    'incomeTaxExpense': '13372000000',
#    'interestAndDebtExpense': '3240000000',
#    'netIncomeFromContinuingOperations': '59531000000',
#    'comprehensiveIncomeNetOfTax': '56505000000',
#    'ebit': '76143000000',
#    'ebitda': '81801000000',
#    'netIncome': '59531000000'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '88186000000',
#    'totalRevenue': '229234000000',
#    'costOfRevenue': '141048000000',
#    'costofGoodsAndServicesSold': '141048000000',
#    'operatingIncome': '61344000000',
#    'sellingGeneralAndAdministrative': '15261000000',
#    'researchAndDevelopment': '11581000000',
#    'operatingExpenses': '26842000000',
#    'investmentIncomeNet': '5201000000',
#    'netInterestIncome': '-2323000000',
#    'interestIncome': '5201000000',
#    'interestExpense': '2323000000',
#    'nonInterestIncome': '229234000000',
#    'otherNonOperatingIncome': '-133000000',
#    'depreciation': '8200000000',
#    'depreciationAndAmortization': '1200000000',
#    'incomeBeforeTax': '64089000000',
#    'incomeTaxExpense': '15738000000',
#    'interestAndDebtExpense': '2323000000',
#    'netIncomeFromContinuingOperations': '48351000000',
#    'comprehensiveIncomeNetOfTax': '47567000000',
#    'ebit': '66412000000',
#    'ebitda': '67612000000',
#    'netIncome': '48351000000'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '84263000000',
#    'totalRevenue': '215639000000',
#    'costOfRevenue': '131376000000',
#    'costofGoodsAndServicesSold': '131376000000',
#    'operatingIncome': '60024000000',
#    'sellingGeneralAndAdministrative': '14194000000',
#    'researchAndDevelopment': '10045000000',
#    'operatingExpenses': '24239000000',
#    'investmentIncomeNet': '3999000000',
#    'netInterestIncome': '-1456000000',
#    'interestIncome': '3999000000',
#    'interestExpense': '1456000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-1195000000',
#    'depreciation': '8300000000',
#    'depreciationAndAmortization': '8300000000',
#    'incomeBeforeTax': '61372000000',
#    'incomeTaxExpense': '15685000000',
#    'interestAndDebtExpense': '1456000000',
#    'netIncomeFromContinuingOperations': '45687000000',
#    'comprehensiveIncomeNetOfTax': '46666000000',
#    'ebit': '62828000000',
#    'ebitda': '71128000000',
#    'netIncome': '45687000000'},
#   {'fiscalDateEnding': '2015-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '93626000000',
#    'totalRevenue': '232982000000',
#    'costOfRevenue': '163618000000',
#    'costofGoodsAndServicesSold': '140089000000',
#    'operatingIncome': '71230000000',
#    'sellingGeneralAndAdministrative': '14329000000',
#    'researchAndDevelopment': '8067000000',
#    'operatingExpenses': '22396000000',
#    'investmentIncomeNet': '2921000000',
#    'netInterestIncome': '-733000000',
#    'interestIncome': 'None',
#    'interestExpense': '733000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-903000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '9200000000',
#    'incomeBeforeTax': '72515000000',
#    'incomeTaxExpense': '19121000000',
#    'interestAndDebtExpense': '733000000',
#    'netIncomeFromContinuingOperations': '53394000000',
#    'comprehensiveIncomeNetOfTax': '51967000000',
#    'ebit': '73248000000',
#    'ebitda': '82448000000',
#    'netIncome': '53394000000'},
#   {'fiscalDateEnding': '2014-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '70537000000',
#    'totalRevenue': '182411000000',
#    'costOfRevenue': '131151000000',
#    'costofGoodsAndServicesSold': '112258000000',
#    'operatingIncome': '52503000000',
#    'sellingGeneralAndAdministrative': '11993000000',
#    'researchAndDevelopment': '6041000000',
#    'operatingExpenses': '18034000000',
#    'investmentIncomeNet': '1795000000',
#    'netInterestIncome': '-384000000',
#    'interestIncome': 'None',
#    'interestExpense': '384000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-431000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '6900000000',
#    'incomeBeforeTax': '53483000000',
#    'incomeTaxExpense': '13973000000',
#    'interestAndDebtExpense': '384000000',
#    'netIncomeFromContinuingOperations': '39510000000',
#    'comprehensiveIncomeNetOfTax': '41063000000',
#    'ebit': '53867000000',
#    'ebitda': '60767000000',
#    'netIncome': '39510000000'},
#   {'fiscalDateEnding': '2013-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '64304000000',
#    'totalRevenue': '170774000000',
#    'costOfRevenue': '123236000000',
#    'costofGoodsAndServicesSold': '106606000000',
#    'operatingIncome': '48999000000',
#    'sellingGeneralAndAdministrative': '10830000000',
#    'researchAndDevelopment': '4475000000',
#    'operatingExpenses': '15305000000',
#    'investmentIncomeNet': '1616000000',
#    'netInterestIncome': '-136000000',
#    'interestIncome': 'None',
#    'interestExpense': '136000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-324000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '5800000000',
#    'incomeBeforeTax': '50155000000',
#    'incomeTaxExpense': '13118000000',
#    'interestAndDebtExpense': '136000000',
#    'netIncomeFromContinuingOperations': '37037000000',
#    'comprehensiveIncomeNetOfTax': '36067000000',
#    'ebit': '50291000000',
#    'ebitda': '56091000000',
#    'netIncome': '37037000000'},
#   {'fiscalDateEnding': '2012-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '68662000000',
#    'totalRevenue': '156508000000',
#    'costOfRevenue': '100486000000',
#    'costofGoodsAndServicesSold': '87846000000',
#    'operatingIncome': '55241000000',
#    'sellingGeneralAndAdministrative': '10040000000',
#    'researchAndDevelopment': '3381000000',
#    'operatingExpenses': '13421000000',
#    'investmentIncomeNet': '1088000000',
#    'netInterestIncome': '0',
#    'interestIncome': 'None',
#    'interestExpense': '0',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-566000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2600000000',
#    'incomeBeforeTax': '55763000000',
#    'incomeTaxExpense': '14030000000',
#    'interestAndDebtExpense': '0',
#    'netIncomeFromContinuingOperations': '41733000000',
#    'comprehensiveIncomeNetOfTax': '41789000000',
#    'ebit': '55763000000',
#    'ebitda': '58363000000',
#    'netIncome': '41733000000'},
#   {'fiscalDateEnding': '2011-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '43818000000',
#    'totalRevenue': '108249000000',
#    'costOfRevenue': '73630000000',
#    'costofGoodsAndServicesSold': '64431000000',
#    'operatingIncome': '33790000000',
#    'sellingGeneralAndAdministrative': '7599000000',
#    'researchAndDevelopment': '2429000000',
#    'operatingExpenses': '10028000000',
#    'investmentIncomeNet': '519000000',
#    'netInterestIncome': '0',
#    'interestIncome': 'None',
#    'interestExpense': '0',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-104000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '1600000000',
#    'incomeBeforeTax': '34205000000',
#    'incomeTaxExpense': '8283000000',
#    'interestAndDebtExpense': '0',
#    'netIncomeFromContinuingOperations': '25922000000',
#    'comprehensiveIncomeNetOfTax': '26411000000',
#    'ebit': '34205000000',
#    'ebitda': '35805000000',
#    'netIncome': '25922000000'},
#   {'fiscalDateEnding': '2010-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '25684000000',
#    'totalRevenue': '65225000000',
#    'costOfRevenue': '45873000000',
#    'costofGoodsAndServicesSold': '39541000000',
#    'operatingIncome': '18385000000',
#    'sellingGeneralAndAdministrative': '5517000000',
#    'researchAndDevelopment': '1782000000',
#    'operatingExpenses': '7299000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '155000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '155000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '815000000',
#    'incomeBeforeTax': '18540000000',
#    'incomeTaxExpense': '4527000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '14013000000',
#    'comprehensiveIncomeNetOfTax': '13890000000',
#    'ebit': '18385000000',
#    'ebitda': '19200000000',
#    'netIncome': '14013000000'},
#   {'fiscalDateEnding': '2009-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '17222000000',
#    'totalRevenue': '42905000000',
#    'costOfRevenue': '29832000000',
#    'costofGoodsAndServicesSold': '25683000000',
#    'operatingIncome': '11740000000',
#    'sellingGeneralAndAdministrative': '4149000000',
#    'researchAndDevelopment': '1333000000',
#    'operatingExpenses': '5482000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '326000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '326000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '606000000',
#    'incomeBeforeTax': '12066000000',
#    'incomeTaxExpense': '3831000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '8235000000',
#    'comprehensiveIncomeNetOfTax': '8321000000',
#    'ebit': '11740000000',
#    'ebitda': '12346000000',
#    'netIncome': '8235000000'}],
#  'quarterlyReports': [{'fiscalDateEnding': '2023-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '54855000000',
#    'totalRevenue': '119575000000',
#    'costOfRevenue': '71506000000',
#    'costofGoodsAndServicesSold': '64720000000',
#    'operatingIncome': '40373000000',
#    'sellingGeneralAndAdministrative': '6786000000',
#    'researchAndDevelopment': '7696000000',
#    'operatingExpenses': '14482000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': 'None',
#    'nonInterestIncome': '119575000000',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2848000000',
#    'incomeBeforeTax': '40323000000',
#    'incomeTaxExpense': '6407000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '33916000000',
#    'comprehensiveIncomeNetOfTax': '35990000000',
#    'ebit': '40373000000',
#    'ebitda': '43221000000',
#    'netIncome': '33916000000'},
#   {'fiscalDateEnding': '2023-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '40427000000',
#    'totalRevenue': '88496000000',
#    'costOfRevenue': '55222000000',
#    'costofGoodsAndServicesSold': '49071000000',
#    'operatingIncome': '26969000000',
#    'sellingGeneralAndAdministrative': '6151000000',
#    'researchAndDevelopment': '7307000000',
#    'operatingExpenses': '13458000000',
#    'investmentIncomeNet': '984000000',
#    'netInterestIncome': '-1002000000',
#    'interestIncome': '18000000',
#    'interestExpense': '1002000000',
#    'nonInterestIncome': '89498000000',
#    'otherNonOperatingIncome': '47000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2653000000',
#    'incomeBeforeTax': '26998000000',
#    'incomeTaxExpense': '4042000000',
#    'interestAndDebtExpense': '1002000000',
#    'netIncomeFromContinuingOperations': '22956000000',
#    'comprehensiveIncomeNetOfTax': '23305000000',
#    'ebit': '28000000000',
#    'ebitda': '29622000000',
#    'netIncome': '22956000000'},
#   {'fiscalDateEnding': '2023-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '36413000000',
#    'totalRevenue': '80799000000',
#    'costOfRevenue': '51357000000',
#    'costofGoodsAndServicesSold': '45384000000',
#    'operatingIncome': '22998000000',
#    'sellingGeneralAndAdministrative': '5973000000',
#    'researchAndDevelopment': '7442000000',
#    'operatingExpenses': '13415000000',
#    'investmentIncomeNet': '980000000',
#    'netInterestIncome': '-998000000',
#    'interestIncome': '18000000',
#    'interestExpense': '998000000',
#    'nonInterestIncome': '81797000000',
#    'otherNonOperatingIncome': '-247000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '3052000000',
#    'incomeBeforeTax': '22733000000',
#    'incomeTaxExpense': '2852000000',
#    'interestAndDebtExpense': '998000000',
#    'netIncomeFromContinuingOperations': '19881000000',
#    'comprehensiveIncomeNetOfTax': '19826000000',
#    'ebit': '23731000000',
#    'ebitda': '26050000000',
#    'netIncome': '19881000000'},
#   {'fiscalDateEnding': '2023-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '41976000000',
#    'totalRevenue': '94836000000',
#    'costOfRevenue': '52860000000',
#    'costofGoodsAndServicesSold': '52860000000',
#    'operatingIncome': '28318000000',
#    'sellingGeneralAndAdministrative': '6201000000',
#    'researchAndDevelopment': '7457000000',
#    'operatingExpenses': '13658000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-12000000',
#    'interestIncome': '12000000',
#    'interestExpense': '930000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '76000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2898000000',
#    'incomeBeforeTax': '28382000000',
#    'incomeTaxExpense': '4222000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '24160000000',
#    'comprehensiveIncomeNetOfTax': '25326000000',
#    'ebit': '29312000000',
#    'ebitda': '31216000000',
#    'netIncome': '24160000000'},
#   {'fiscalDateEnding': '2022-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '50332000000',
#    'totalRevenue': '116151000000',
#    'costOfRevenue': '73429000000',
#    'costofGoodsAndServicesSold': '66822000000',
#    'operatingIncome': '36016000000',
#    'sellingGeneralAndAdministrative': '6607000000',
#    'researchAndDevelopment': '7709000000',
#    'operatingExpenses': '14316000000',
#    'investmentIncomeNet': '868000000',
#    'netInterestIncome': '-1003000000',
#    'interestIncome': '135000000',
#    'interestExpense': '1003000000',
#    'nonInterestIncome': '117154000000',
#    'otherNonOperatingIncome': '-258000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2916000000',
#    'incomeBeforeTax': '35623000000',
#    'incomeTaxExpense': '5625000000',
#    'interestAndDebtExpense': '1003000000',
#    'netIncomeFromContinuingOperations': '29998000000',
#    'comprehensiveIncomeNetOfTax': '28195000000',
#    'ebit': '36626000000',
#    'ebitda': '38932000000',
#    'netIncome': '29998000000'},
#   {'fiscalDateEnding': '2022-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '38095000000',
#    'totalRevenue': '89319000000',
#    'costOfRevenue': '58491000000',
#    'costofGoodsAndServicesSold': '52051000000',
#    'operatingIncome': '24894000000',
#    'sellingGeneralAndAdministrative': '6440000000',
#    'researchAndDevelopment': '6761000000',
#    'operatingExpenses': '13201000000',
#    'investmentIncomeNet': '753000000',
#    'netInterestIncome': '-827000000',
#    'interestIncome': '74000000',
#    'interestExpense': '827000000',
#    'nonInterestIncome': '90146000000',
#    'otherNonOperatingIncome': '-163000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2865000000',
#    'incomeBeforeTax': '24657000000',
#    'incomeTaxExpense': '3936000000',
#    'interestAndDebtExpense': '827000000',
#    'netIncomeFromContinuingOperations': '20721000000',
#    'comprehensiveIncomeNetOfTax': '18909000000',
#    'ebit': '25484000000',
#    'ebitda': '27759000000',
#    'netIncome': '20721000000'},
#   {'fiscalDateEnding': '2022-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '35885000000',
#    'totalRevenue': '82240000000',
#    'costOfRevenue': '53086000000',
#    'costofGoodsAndServicesSold': '47074000000',
#    'operatingIncome': '23076000000',
#    'sellingGeneralAndAdministrative': '6012000000',
#    'researchAndDevelopment': '6797000000',
#    'operatingExpenses': '12809000000',
#    'investmentIncomeNet': '722000000',
#    'netInterestIncome': '-719000000',
#    'interestIncome': '722000000',
#    'interestExpense': '719000000',
#    'nonInterestIncome': '82959000000',
#    'otherNonOperatingIncome': '-13000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2805000000',
#    'incomeBeforeTax': '23066000000',
#    'incomeTaxExpense': '3624000000',
#    'interestAndDebtExpense': '719000000',
#    'netIncomeFromContinuingOperations': '19442000000',
#    'comprehensiveIncomeNetOfTax': '16639000000',
#    'ebit': '23785000000',
#    'ebitda': '25881000000',
#    'netIncome': '19442000000'},
#   {'fiscalDateEnding': '2022-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '42559000000',
#    'totalRevenue': '96587000000',
#    'costOfRevenue': '60912000000',
#    'costofGoodsAndServicesSold': '54719000000',
#    'operatingIncome': '29979000000',
#    'sellingGeneralAndAdministrative': '6193000000',
#    'researchAndDevelopment': '6387000000',
#    'operatingExpenses': '12580000000',
#    'investmentIncomeNet': '700000000',
#    'netInterestIncome': '-691000000',
#    'interestIncome': '700000000',
#    'interestExpense': '691000000',
#    'nonInterestIncome': '97278000000',
#    'otherNonOperatingIncome': '151000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2737000000',
#    'incomeBeforeTax': '30139000000',
#    'incomeTaxExpense': '5129000000',
#    'interestAndDebtExpense': '691000000',
#    'netIncomeFromContinuingOperations': '25010000000',
#    'comprehensiveIncomeNetOfTax': '19443000000',
#    'ebit': '30830000000',
#    'ebitda': '32716000000',
#    'netIncome': '25010000000'},
#   {'fiscalDateEnding': '2021-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '54243000000',
#    'totalRevenue': '123251000000',
#    'costOfRevenue': '76151000000',
#    'costofGoodsAndServicesSold': '69702000000',
#    'operatingIncome': '41488000000',
#    'sellingGeneralAndAdministrative': '6449000000',
#    'researchAndDevelopment': '6306000000',
#    'operatingExpenses': '12755000000',
#    'investmentIncomeNet': '650000000',
#    'netInterestIncome': '-694000000',
#    'interestIncome': '650000000',
#    'interestExpense': '694000000',
#    'nonInterestIncome': '123945000000',
#    'otherNonOperatingIncome': '-203000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2697000000',
#    'incomeBeforeTax': '41241000000',
#    'incomeTaxExpense': '6611000000',
#    'interestAndDebtExpense': '694000000',
#    'netIncomeFromContinuingOperations': '34630000000',
#    'comprehensiveIncomeNetOfTax': '33540000000',
#    'ebit': '41935000000',
#    'ebitda': '44185000000',
#    'netIncome': '34630000000'},
#   {'fiscalDateEnding': '2021-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '35174000000',
#    'totalRevenue': '82688000000',
#    'costOfRevenue': '53802000000',
#    'costofGoodsAndServicesSold': '48186000000',
#    'operatingIncome': '23786000000',
#    'sellingGeneralAndAdministrative': '5616000000',
#    'researchAndDevelopment': '5772000000',
#    'operatingExpenses': '11388000000',
#    'investmentIncomeNet': '659000000',
#    'netInterestIncome': '-672000000',
#    'interestIncome': '659000000',
#    'interestExpense': '672000000',
#    'nonInterestIncome': '83360000000',
#    'otherNonOperatingIncome': '-525000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2989000000',
#    'incomeBeforeTax': '23248000000',
#    'incomeTaxExpense': '2697000000',
#    'interestAndDebtExpense': '672000000',
#    'netIncomeFromContinuingOperations': '20551000000',
#    'comprehensiveIncomeNetOfTax': '20656000000',
#    'ebit': '23920000000',
#    'ebitda': '26775000000',
#    'netIncome': '20551000000'},
#   {'fiscalDateEnding': '2021-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '35255000000',
#    'totalRevenue': '80769000000',
#    'costOfRevenue': '51591000000',
#    'costofGoodsAndServicesSold': '46179000000',
#    'operatingIncome': '24126000000',
#    'sellingGeneralAndAdministrative': '5412000000',
#    'researchAndDevelopment': '5717000000',
#    'operatingExpenses': '11129000000',
#    'investmentIncomeNet': '719000000',
#    'netInterestIncome': '-665000000',
#    'interestIncome': '719000000',
#    'interestExpense': '665000000',
#    'nonInterestIncome': '81434000000',
#    'otherNonOperatingIncome': '189000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2832000000',
#    'incomeBeforeTax': '24369000000',
#    'incomeTaxExpense': '2625000000',
#    'interestAndDebtExpense': '665000000',
#    'netIncomeFromContinuingOperations': '21744000000',
#    'comprehensiveIncomeNetOfTax': '22088000000',
#    'ebit': '25034000000',
#    'ebitda': '26958000000',
#    'netIncome': '21744000000'},
#   {'fiscalDateEnding': '2021-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '38079000000',
#    'totalRevenue': '88914000000',
#    'costOfRevenue': '56819000000',
#    'costofGoodsAndServicesSold': '51505000000',
#    'operatingIncome': '27503000000',
#    'sellingGeneralAndAdministrative': '5314000000',
#    'researchAndDevelopment': '5262000000',
#    'operatingExpenses': '10576000000',
#    'investmentIncomeNet': '718000000',
#    'netInterestIncome': '-670000000',
#    'interestIncome': '718000000',
#    'interestExpense': '670000000',
#    'nonInterestIncome': '89584000000',
#    'otherNonOperatingIncome': '460000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2797000000',
#    'incomeBeforeTax': '28011000000',
#    'incomeTaxExpense': '4381000000',
#    'interestAndDebtExpense': '670000000',
#    'netIncomeFromContinuingOperations': '23630000000',
#    'comprehensiveIncomeNetOfTax': '23165000000',
#    'ebit': '28681000000',
#    'ebitda': '30300000000',
#    'netIncome': '23630000000'},
#   {'fiscalDateEnding': '2020-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '44328000000',
#    'totalRevenue': '110801000000',
#    'costOfRevenue': '72742000000',
#    'costofGoodsAndServicesSold': '67111000000',
#    'operatingIncome': '33534000000',
#    'sellingGeneralAndAdministrative': '5631000000',
#    'researchAndDevelopment': '5163000000',
#    'operatingExpenses': '10794000000',
#    'investmentIncomeNet': '747000000',
#    'netInterestIncome': '-638000000',
#    'interestIncome': '747000000',
#    'interestExpense': '638000000',
#    'nonInterestIncome': '111439000000',
#    'otherNonOperatingIncome': '-64000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2666000000',
#    'incomeBeforeTax': '33579000000',
#    'incomeTaxExpense': '4824000000',
#    'interestAndDebtExpense': '638000000',
#    'netIncomeFromContinuingOperations': '28755000000',
#    'comprehensiveIncomeNetOfTax': '29340000000',
#    'ebit': '34217000000',
#    'ebitda': '36200000000',
#    'netIncome': '28755000000'},
#   {'fiscalDateEnding': '2020-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '24689000000',
#    'totalRevenue': '64698000000',
#    'costOfRevenue': '44945000000',
#    'costofGoodsAndServicesSold': '40009000000',
#    'operatingIncome': '14775000000',
#    'sellingGeneralAndAdministrative': '4936000000',
#    'researchAndDevelopment': '4978000000',
#    'operatingExpenses': '9914000000',
#    'investmentIncomeNet': '768000000',
#    'netInterestIncome': '-634000000',
#    'interestIncome': '134000000',
#    'interestExpense': '634000000',
#    'nonInterestIncome': '64698000000',
#    'otherNonOperatingIncome': '-8000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2702000000',
#    'incomeBeforeTax': '14901000000',
#    'incomeTaxExpense': '2228000000',
#    'interestAndDebtExpense': '634000000',
#    'netIncomeFromContinuingOperations': '24689000000',
#    'comprehensiveIncomeNetOfTax': '12817000000',
#    'ebit': '15535000000',
#    'ebitda': '17477000000',
#    'netIncome': '12673000000'},
#   {'fiscalDateEnding': '2020-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '22680000000',
#    'totalRevenue': '58988000000',
#    'costOfRevenue': '41836000000',
#    'costofGoodsAndServicesSold': '37005000000',
#    'operatingIncome': '13091000000',
#    'sellingGeneralAndAdministrative': '4831000000',
#    'researchAndDevelopment': '4758000000',
#    'operatingExpenses': '9589000000',
#    'investmentIncomeNet': '901000000',
#    'netInterestIncome': '-697000000',
#    'interestIncome': '901000000',
#    'interestExpense': '697000000',
#    'nonInterestIncome': '59685000000',
#    'otherNonOperatingIncome': '-158000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2752000000',
#    'incomeBeforeTax': '13137000000',
#    'incomeTaxExpense': '1884000000',
#    'interestAndDebtExpense': '697000000',
#    'netIncomeFromContinuingOperations': '11253000000',
#    'comprehensiveIncomeNetOfTax': '13492000000',
#    'ebit': '13834000000',
#    'ebitda': '15843000000',
#    'netIncome': '11253000000'},
#   {'fiscalDateEnding': '2020-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '22370000000',
#    'totalRevenue': '57556000000',
#    'costOfRevenue': '40895000000',
#    'costofGoodsAndServicesSold': '35943000000',
#    'operatingIncome': '12853000000',
#    'sellingGeneralAndAdministrative': '4952000000',
#    'researchAndDevelopment': '4565000000',
#    'operatingExpenses': '9517000000',
#    'investmentIncomeNet': '1049000000',
#    'netInterestIncome': '-757000000',
#    'interestIncome': '1049000000',
#    'interestExpense': '757000000',
#    'nonInterestIncome': '58313000000',
#    'otherNonOperatingIncome': '-10000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2786000000',
#    'incomeBeforeTax': '13135000000',
#    'incomeTaxExpense': '1886000000',
#    'interestAndDebtExpense': '757000000',
#    'netIncomeFromContinuingOperations': '11249000000',
#    'comprehensiveIncomeNetOfTax': '8878000000',
#    'ebit': '13892000000',
#    'ebitda': '15639000000',
#    'netIncome': '11249000000'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '35217000000',
#    'totalRevenue': '91034000000',
#    'costOfRevenue': '61799000000',
#    'costofGoodsAndServicesSold': '56602000000',
#    'operatingIncome': '25569000000',
#    'sellingGeneralAndAdministrative': '5197000000',
#    'researchAndDevelopment': '4451000000',
#    'operatingExpenses': '9648000000',
#    'investmentIncomeNet': '1045000000',
#    'netInterestIncome': '-785000000',
#    'interestIncome': '1045000000',
#    'interestExpense': '785000000',
#    'nonInterestIncome': '91819000000',
#    'otherNonOperatingIncome': '89000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2816000000',
#    'incomeBeforeTax': '25918000000',
#    'incomeTaxExpense': '3682000000',
#    'interestAndDebtExpense': '785000000',
#    'netIncomeFromContinuingOperations': '22236000000',
#    'comprehensiveIncomeNetOfTax': '22266000000',
#    'ebit': '26703000000',
#    'ebitda': '28385000000',
#    'netIncome': '22236000000'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '24313000000',
#    'totalRevenue': '64040000000',
#    'costOfRevenue': '44305000000',
#    'costofGoodsAndServicesSold': '39727000000',
#    'operatingIncome': '15625000000',
#    'sellingGeneralAndAdministrative': '4578000000',
#    'researchAndDevelopment': '4110000000',
#    'operatingExpenses': '8688000000',
#    'investmentIncomeNet': '1106000000',
#    'netInterestIncome': '-810000000',
#    'interestIncome': '1106000000',
#    'interestExpense': '810000000',
#    'nonInterestIncome': '64040000000',
#    'otherNonOperatingIncome': '206000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '3179000000',
#    'incomeBeforeTax': '16127000000',
#    'incomeTaxExpense': '2441000000',
#    'interestAndDebtExpense': '810000000',
#    'netIncomeFromContinuingOperations': '24313000000',
#    'comprehensiveIncomeNetOfTax': '13741000000',
#    'ebit': '16937000000',
#    'ebitda': '18804000000',
#    'netIncome': '13686000000'},
#   {'fiscalDateEnding': '2019-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '20227000000',
#    'totalRevenue': '52943000000',
#    'costOfRevenue': '38008000000',
#    'costofGoodsAndServicesSold': '33582000000',
#    'operatingIncome': '11544000000',
#    'sellingGeneralAndAdministrative': '4426000000',
#    'researchAndDevelopment': '4257000000',
#    'operatingExpenses': '8683000000',
#    'investmentIncomeNet': '1190000000',
#    'netInterestIncome': '-866000000',
#    'interestIncome': '1190000000',
#    'interestExpense': '866000000',
#    'nonInterestIncome': '53809000000',
#    'otherNonOperatingIncome': '43000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2933000000',
#    'incomeBeforeTax': '11911000000',
#    'incomeTaxExpense': '1867000000',
#    'interestAndDebtExpense': '866000000',
#    'netIncomeFromContinuingOperations': '10044000000',
#    'comprehensiveIncomeNetOfTax': '10904000000',
#    'ebit': '12777000000',
#    'ebitda': '14477000000',
#    'netIncome': '10044000000'},
#   {'fiscalDateEnding': '2019-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '21821000000',
#    'totalRevenue': '57005000000',
#    'costOfRevenue': '40652000000',
#    'costofGoodsAndServicesSold': '36194000000',
#    'operatingIncome': '13415000000',
#    'sellingGeneralAndAdministrative': '4458000000',
#    'researchAndDevelopment': '3948000000',
#    'operatingExpenses': '8406000000',
#    'investmentIncomeNet': '1358000000',
#    'netInterestIncome': '-1010000000',
#    'interestIncome': '1358000000',
#    'interestExpense': '1010000000',
#    'nonInterestIncome': '58015000000',
#    'otherNonOperatingIncome': '30000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '3040000000',
#    'incomeBeforeTax': '13793000000',
#    'incomeTaxExpense': '2232000000',
#    'interestAndDebtExpense': '1010000000',
#    'netIncomeFromContinuingOperations': '11561000000',
#    'comprehensiveIncomeNetOfTax': '13650000000',
#    'ebit': '14803000000',
#    'ebitda': '16455000000',
#    'netIncome': '11561000000'},
#   {'fiscalDateEnding': '2018-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '32031000000',
#    'totalRevenue': '83420000000',
#    'costOfRevenue': '57062000000',
#    'costofGoodsAndServicesSold': '52279000000',
#    'operatingIncome': '23346000000',
#    'sellingGeneralAndAdministrative': '4783000000',
#    'researchAndDevelopment': '3902000000',
#    'operatingExpenses': '8685000000',
#    'investmentIncomeNet': '1307000000',
#    'netInterestIncome': '-890000000',
#    'interestIncome': 'None',
#    'interestExpense': '890000000',
#    'nonInterestIncome': '84310000000',
#    'otherNonOperatingIncome': '143000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '3395000000',
#    'incomeBeforeTax': '23906000000',
#    'incomeTaxExpense': '3941000000',
#    'interestAndDebtExpense': '890000000',
#    'netIncomeFromContinuingOperations': '19965000000',
#    'comprehensiveIncomeNetOfTax': '19742000000',
#    'ebit': '24796000000',
#    'ebitda': '26741000000',
#    'netIncome': '19965000000'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '24084000000',
#    'totalRevenue': '62900000000',
#    'costOfRevenue': '38816000000',
#    'costofGoodsAndServicesSold': '38816000000',
#    'operatingIncome': '16118000000',
#    'sellingGeneralAndAdministrative': '4216000000',
#    'researchAndDevelopment': '3750000000',
#    'operatingExpenses': '7966000000',
#    'investmentIncomeNet': '1311000000',
#    'netInterestIncome': '-868000000',
#    'interestIncome': 'None',
#    'interestExpense': '868000000',
#    'nonInterestIncome': '62900000000',
#    'otherNonOperatingIncome': '-140000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2754000000',
#    'incomeBeforeTax': '16421000000',
#    'incomeTaxExpense': '2296000000',
#    'interestAndDebtExpense': '868000000',
#    'netIncomeFromContinuingOperations': '24084000000',
#    'comprehensiveIncomeNetOfTax': '13782000000',
#    'ebit': '17289000000',
#    'ebitda': '18872000000',
#    'netIncome': '14125000000'},
#   {'fiscalDateEnding': '2018-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '20421000000',
#    'totalRevenue': '53265000000',
#    'costOfRevenue': '32844000000',
#    'costofGoodsAndServicesSold': '32844000000',
#    'operatingIncome': '12612000000',
#    'sellingGeneralAndAdministrative': '4108000000',
#    'researchAndDevelopment': '3701000000',
#    'operatingExpenses': '7809000000',
#    'investmentIncomeNet': '1418000000',
#    'netInterestIncome': '-846000000',
#    'interestIncome': 'None',
#    'interestExpense': '846000000',
#    'nonInterestIncome': '53265000000',
#    'otherNonOperatingIncome': '100000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2665000000',
#    'incomeBeforeTax': '13284000000',
#    'incomeTaxExpense': '1765000000',
#    'interestAndDebtExpense': '846000000',
#    'netIncomeFromContinuingOperations': '11519000000',
#    'comprehensiveIncomeNetOfTax': '11472000000',
#    'ebit': '14130000000',
#    'ebitda': '15277000000',
#    'netIncome': '11519000000'},
#   {'fiscalDateEnding': '2018-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '23422000000',
#    'totalRevenue': '61137000000',
#    'costOfRevenue': '37715000000',
#    'costofGoodsAndServicesSold': '37715000000',
#    'operatingIncome': '15894000000',
#    'sellingGeneralAndAdministrative': '4150000000',
#    'researchAndDevelopment': '3378000000',
#    'operatingExpenses': '7528000000',
#    'investmentIncomeNet': '1505000000',
#    'netInterestIncome': '-792000000',
#    'interestIncome': 'None',
#    'interestExpense': '792000000',
#    'nonInterestIncome': '61137000000',
#    'otherNonOperatingIncome': '-439000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2739000000',
#    'incomeBeforeTax': '16168000000',
#    'incomeTaxExpense': '2346000000',
#    'interestAndDebtExpense': '792000000',
#    'netIncomeFromContinuingOperations': '13822000000',
#    'comprehensiveIncomeNetOfTax': '11877000000',
#    'ebit': '16960000000',
#    'ebitda': '18633000000',
#    'netIncome': '13822000000'},
#   {'fiscalDateEnding': '2017-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '33912000000',
#    'totalRevenue': '88293000000',
#    'costOfRevenue': '54381000000',
#    'costofGoodsAndServicesSold': '54381000000',
#    'operatingIncome': '26274000000',
#    'sellingGeneralAndAdministrative': '4231000000',
#    'researchAndDevelopment': '3407000000',
#    'operatingExpenses': '7638000000',
#    'investmentIncomeNet': '1452000000',
#    'netInterestIncome': '-734000000',
#    'interestIncome': 'None',
#    'interestExpense': '734000000',
#    'nonInterestIncome': '88293000000',
#    'otherNonOperatingIncome': '38000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2745000000',
#    'incomeBeforeTax': '27030000000',
#    'incomeTaxExpense': '6965000000',
#    'interestAndDebtExpense': '734000000',
#    'netIncomeFromContinuingOperations': '20065000000',
#    'comprehensiveIncomeNetOfTax': '19374000000',
#    'ebit': '27764000000',
#    'ebitda': '29019000000',
#    'netIncome': '20065000000'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '19931000000',
#    'totalRevenue': '52579000000',
#    'costOfRevenue': '32648000000',
#    'costofGoodsAndServicesSold': '32648000000',
#    'operatingIncome': '13120000000',
#    'sellingGeneralAndAdministrative': '3814000000',
#    'researchAndDevelopment': '2997000000',
#    'operatingExpenses': '6811000000',
#    'investmentIncomeNet': '1368000000',
#    'netInterestIncome': '-666000000',
#    'interestIncome': 'None',
#    'interestExpense': '666000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '95000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2484000000',
#    'incomeBeforeTax': '13917000000',
#    'incomeTaxExpense': '3203000000',
#    'interestAndDebtExpense': '666000000',
#    'netIncomeFromContinuingOperations': '19931000000',
#    'comprehensiveIncomeNetOfTax': '11109000000',
#    'ebit': '14583000000',
#    'ebitda': '15604000000',
#    'netIncome': '10714000000'},
#   {'fiscalDateEnding': '2017-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '17488000000',
#    'totalRevenue': '45408000000',
#    'costOfRevenue': '27920000000',
#    'costofGoodsAndServicesSold': '27920000000',
#    'operatingIncome': '10768000000',
#    'sellingGeneralAndAdministrative': '3783000000',
#    'researchAndDevelopment': '2937000000',
#    'operatingExpenses': '6720000000',
#    'investmentIncomeNet': '1327000000',
#    'netInterestIncome': '-602000000',
#    'interestIncome': 'None',
#    'interestExpense': '602000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-185000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2354000000',
#    'incomeBeforeTax': '11308000000',
#    'incomeTaxExpense': '2591000000',
#    'interestAndDebtExpense': '602000000',
#    'netIncomeFromContinuingOperations': '17488000000',
#    'comprehensiveIncomeNetOfTax': '8594000000',
#    'ebit': '11910000000',
#    'ebitda': '13122000000',
#    'netIncome': '8717000000'},
#   {'fiscalDateEnding': '2017-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '20591000000',
#    'totalRevenue': '52896000000',
#    'costOfRevenue': '32305000000',
#    'costofGoodsAndServicesSold': '32305000000',
#    'operatingIncome': '14097000000',
#    'sellingGeneralAndAdministrative': '3718000000',
#    'researchAndDevelopment': '2776000000',
#    'operatingExpenses': '6494000000',
#    'investmentIncomeNet': '1282000000',
#    'netInterestIncome': '-530000000',
#    'interestIncome': 'None',
#    'interestExpense': '530000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-165000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2332000000',
#    'incomeBeforeTax': '14684000000',
#    'incomeTaxExpense': '3655000000',
#    'interestAndDebtExpense': '530000000',
#    'netIncomeFromContinuingOperations': '20591000000',
#    'comprehensiveIncomeNetOfTax': '10362000000',
#    'ebit': '15214000000',
#    'ebitda': '16429000000',
#    'netIncome': '11029000000'},
#   {'fiscalDateEnding': '2016-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '30176000000',
#    'totalRevenue': '78351000000',
#    'costOfRevenue': '48175000000',
#    'costofGoodsAndServicesSold': '48175000000',
#    'operatingIncome': '23359000000',
#    'sellingGeneralAndAdministrative': '3946000000',
#    'researchAndDevelopment': '2871000000',
#    'operatingExpenses': '6817000000',
#    'investmentIncomeNet': '1224000000',
#    'netInterestIncome': '-525000000',
#    'interestIncome': 'None',
#    'interestExpense': '525000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '122000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2987000000',
#    'incomeBeforeTax': '24180000000',
#    'incomeTaxExpense': '6289000000',
#    'interestAndDebtExpense': '525000000',
#    'netIncomeFromContinuingOperations': '17891000000',
#    'comprehensiveIncomeNetOfTax': '17502000000',
#    'ebit': '24705000000',
#    'ebitda': '26346000000',
#    'netIncome': '17891000000'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '17813000000',
#    'totalRevenue': '47858000000',
#    'costOfRevenue': '40821000000',
#    'costofGoodsAndServicesSold': '29039000000',
#    'operatingIncome': '11761000000',
#    'sellingGeneralAndAdministrative': '3482000000',
#    'researchAndDevelopment': '2570000000',
#    'operatingExpenses': '6052000000',
#    'investmentIncomeNet': '1036000000',
#    'netInterestIncome': '-450000000',
#    'interestIncome': 'None',
#    'interestExpense': '450000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-159000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2548000000',
#    'incomeBeforeTax': '12188000000',
#    'incomeTaxExpense': '3174000000',
#    'interestAndDebtExpense': '450000000',
#    'netIncomeFromContinuingOperations': '17813000000',
#    'comprehensiveIncomeNetOfTax': '9755000000',
#    'ebit': '12638000000',
#    'ebitda': '14309000000',
#    'netIncome': '9014000000'},
#   {'fiscalDateEnding': '2016-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '16106000000',
#    'totalRevenue': '41949000000',
#    'costOfRevenue': '29693000000',
#    'costofGoodsAndServicesSold': '26252000000',
#    'operatingIncome': '10105000000',
#    'sellingGeneralAndAdministrative': '3441000000',
#    'researchAndDevelopment': '2560000000',
#    'operatingExpenses': '6001000000',
#    'investmentIncomeNet': '1036000000',
#    'netInterestIncome': '-409000000',
#    'interestIncome': 'None',
#    'interestExpense': '409000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-263000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2526000000',
#    'incomeBeforeTax': '10469000000',
#    'incomeTaxExpense': '2673000000',
#    'interestAndDebtExpense': '409000000',
#    'netIncomeFromContinuingOperations': '7796000000',
#    'comprehensiveIncomeNetOfTax': '8737000000',
#    'ebit': '10878000000',
#    'ebitda': '12631000000',
#    'netIncome': '7796000000'},
#   {'fiscalDateEnding': '2016-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '19921000000',
#    'totalRevenue': '50236000000',
#    'costOfRevenue': '34059000000',
#    'costofGoodsAndServicesSold': '30636000000',
#    'operatingIncome': '13987000000',
#    'sellingGeneralAndAdministrative': '3423000000',
#    'researchAndDevelopment': '2511000000',
#    'operatingExpenses': '5934000000',
#    'investmentIncomeNet': '986000000',
#    'netInterestIncome': '-321000000',
#    'interestIncome': 'None',
#    'interestExpense': '321000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-510000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2477000000',
#    'incomeBeforeTax': '14142000000',
#    'incomeTaxExpense': '3626000000',
#    'interestAndDebtExpense': '321000000',
#    'netIncomeFromContinuingOperations': '10516000000',
#    'comprehensiveIncomeNetOfTax': '10948000000',
#    'ebit': '14463000000',
#    'ebitda': '16464000000',
#    'netIncome': '10516000000'},
#   {'fiscalDateEnding': '2015-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '30423000000',
#    'totalRevenue': '75596000000',
#    'costOfRevenue': '49297000000',
#    'costofGoodsAndServicesSold': '45449000000',
#    'operatingIncome': '24171000000',
#    'sellingGeneralAndAdministrative': '3848000000',
#    'researchAndDevelopment': '2404000000',
#    'operatingExpenses': '6252000000',
#    'investmentIncomeNet': '941000000',
#    'netInterestIncome': '-276000000',
#    'interestIncome': 'None',
#    'interestExpense': '276000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '-263000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '2954000000',
#    'incomeBeforeTax': '24573000000',
#    'incomeTaxExpense': '6212000000',
#    'interestAndDebtExpense': '276000000',
#    'netIncomeFromContinuingOperations': '18361000000',
#    'comprehensiveIncomeNetOfTax': '17226000000',
#    'ebit': '24849000000',
#    'ebitda': '27125000000',
#    'netIncome': '18361000000'},
#   {'fiscalDateEnding': '2015-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '20548000000',
#    'totalRevenue': '51501000000',
#    'costOfRevenue': '43858000000',
#    'costofGoodsAndServicesSold': '30953000000',
# ...
#    'operatingIncome': '11573000000',
#    'sellingGeneralAndAdministrative': '2545000000',
#    'researchAndDevelopment': '876000000',
#    'operatingExpenses': '3421000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '288000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '288000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '835000000',
#    'incomeBeforeTax': '11861000000',
#    'incomeTaxExpense': '3037000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '8824000000',
#    'comprehensiveIncomeNetOfTax': '8832000000',
#    'ebit': '11573000000',
#    'ebitda': '12408000000',
#    'netIncome': '8824000000'},
#   {'fiscalDateEnding': '2012-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '18564000000',
#    'totalRevenue': '39186000000',
#    'costOfRevenue': '22961000000',
#    'costofGoodsAndServicesSold': '20622000000',
#    'operatingIncome': '15384000000',
#    'sellingGeneralAndAdministrative': '2339000000',
#    'researchAndDevelopment': '841000000',
#    'operatingExpenses': '3180000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '148000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '148000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '740000000',
#    'incomeBeforeTax': '15532000000',
#    'incomeTaxExpense': '3910000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '11622000000',
#    'comprehensiveIncomeNetOfTax': '11762000000',
#    'ebit': '15384000000',
#    'ebitda': '16124000000',
#    'netIncome': '11622000000'},
#   {'fiscalDateEnding': '2011-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '20703000000',
#    'totalRevenue': '46333000000',
#    'costOfRevenue': '28235000000',
#    'costofGoodsAndServicesSold': '25630000000',
#    'operatingIncome': '17340000000',
#    'sellingGeneralAndAdministrative': '2605000000',
#    'researchAndDevelopment': '758000000',
#    'operatingExpenses': '3363000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '137000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '137000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '721000000',
#    'incomeBeforeTax': '17477000000',
#    'incomeTaxExpense': '4413000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '13064000000',
#    'comprehensiveIncomeNetOfTax': '13005000000',
#    'ebit': '17340000000',
#    'ebitda': '18061000000',
#    'netIncome': '13064000000'},
#   {'fiscalDateEnding': '2011-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '11380000000',
#    'totalRevenue': '28270000000',
#    'costOfRevenue': '20515000000',
#    'costofGoodsAndServicesSold': '16890000000',
#    'operatingIncome': '8710000000',
#    'sellingGeneralAndAdministrative': '2025000000',
#    'researchAndDevelopment': '645000000',
#    'operatingExpenses': '2670000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '81000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '81000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '543000000',
#    'incomeBeforeTax': '8791000000',
#    'incomeTaxExpense': '2168000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '11380000000',
#    'comprehensiveIncomeNetOfTax': '6677000000',
#    'ebit': '8710000000',
#    'ebitda': '9253000000',
#    'netIncome': '6623000000'},
#   {'fiscalDateEnding': '2011-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '11922000000',
#    'totalRevenue': '28571000000',
#    'costOfRevenue': '18564000000',
#    'costofGoodsAndServicesSold': '16649000000',
#    'operatingIncome': '9379000000',
#    'sellingGeneralAndAdministrative': '1915000000',
#    'researchAndDevelopment': '628000000',
#    'operatingExpenses': '2543000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '172000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '172000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '481000000',
#    'incomeBeforeTax': '9551000000',
#    'incomeTaxExpense': '2243000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '7308000000',
#    'comprehensiveIncomeNetOfTax': '7571000000',
#    'ebit': '9379000000',
#    'ebitda': '9860000000',
#    'netIncome': '7308000000'},
#   {'fiscalDateEnding': '2011-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '10218000000',
#    'totalRevenue': '24708000000',
#    'costOfRevenue': '16212000000',
#    'costofGoodsAndServicesSold': '14449000000',
#    'operatingIncome': '7874000000',
#    'sellingGeneralAndAdministrative': '1763000000',
#    'researchAndDevelopment': '581000000',
#    'operatingExpenses': '2344000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '26000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '26000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '434000000',
#    'incomeBeforeTax': '7900000000',
#    'incomeTaxExpense': '1913000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '5987000000',
#    'comprehensiveIncomeNetOfTax': '5999000000',
#    'ebit': '7874000000',
#    'ebitda': '8308000000',
#    'netIncome': '5987000000'},
#   {'fiscalDateEnding': '2010-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '10298000000',
#    'totalRevenue': '26741000000',
#    'costOfRevenue': '18339000000',
#    'costofGoodsAndServicesSold': '16443000000',
#    'operatingIncome': '7827000000',
#    'sellingGeneralAndAdministrative': '1896000000',
#    'researchAndDevelopment': '575000000',
#    'operatingExpenses': '2471000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '136000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '136000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '356000000',
#    'incomeBeforeTax': '7963000000',
#    'incomeTaxExpense': '1959000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '6004000000',
#    'comprehensiveIncomeNetOfTax': '6164000000',
#    'ebit': '7827000000',
#    'ebitda': '8183000000',
#    'netIncome': '6004000000'},
#   {'fiscalDateEnding': '2010-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '7512000000',
#    'totalRevenue': '20343000000',
#    'costOfRevenue': '15217000000',
#    'costofGoodsAndServicesSold': '12831000000',
#    'operatingIncome': '5447000000',
#    'sellingGeneralAndAdministrative': '1571000000',
#    'researchAndDevelopment': '494000000',
#    'operatingExpenses': '2065000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '14000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '14000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '329000000',
#    'incomeBeforeTax': '5461000000',
#    'incomeTaxExpense': '1153000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '7512000000',
#    'comprehensiveIncomeNetOfTax': '4154000000',
#    'ebit': '5447000000',
#    'ebitda': '5776000000',
#    'netIncome': '4308000000'},
#   {'fiscalDateEnding': '2010-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '6136000000',
#    'totalRevenue': '15700000000',
#    'costOfRevenue': '11002000000',
#    'costofGoodsAndServicesSold': '9564000000',
#    'operatingIncome': '4234000000',
#    'sellingGeneralAndAdministrative': '1438000000',
#    'researchAndDevelopment': '464000000',
#    'operatingExpenses': '1902000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '58000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '58000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '273000000',
#    'incomeBeforeTax': '4292000000',
#    'incomeTaxExpense': '1039000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '3253000000',
#    'comprehensiveIncomeNetOfTax': '3236000000',
#    'ebit': '4234000000',
#    'ebitda': '4507000000',
#    'netIncome': '3253000000'},
#   {'fiscalDateEnding': '2010-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '5625000000',
#    'totalRevenue': '13499000000',
#    'costOfRevenue': '9094000000',
#    'costofGoodsAndServicesSold': '7874000000',
#    'operatingIncome': '3979000000',
#    'sellingGeneralAndAdministrative': '1220000000',
#    'researchAndDevelopment': '426000000',
#    'operatingExpenses': '1646000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '266000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '50000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '216000000',
#    'incomeBeforeTax': '4029000000',
#    'incomeTaxExpense': '955000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '3074000000',
#    'comprehensiveIncomeNetOfTax': '3088000000',
#    'ebit': '3979000000',
#    'ebitda': '3979000000',
#    'netIncome': '3074000000'},
#   {'fiscalDateEnding': '2009-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '6411000000',
#    'totalRevenue': '15683000000',
#    'costOfRevenue': '10560000000',
#    'costofGoodsAndServicesSold': '9272000000',
#    'operatingIncome': '4725000000',
#    'sellingGeneralAndAdministrative': '1288000000',
#    'researchAndDevelopment': '398000000',
#    'operatingExpenses': '1686000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '33000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '33000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '209000000',
#    'incomeBeforeTax': '4758000000',
#    'incomeTaxExpense': '1380000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '3378000000',
#    'comprehensiveIncomeNetOfTax': '3412000000',
#    'ebit': '4725000000',
#    'ebitda': '4934000000',
#    'netIncome': '3378000000'},
#   {'fiscalDateEnding': '2009-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '5105000000',
#    'totalRevenue': '12207000000',
#    'costOfRevenue': '7102000000',
#    'costofGoodsAndServicesSold': '7102000000',
#    'operatingIncome': '3684000000',
#    'sellingGeneralAndAdministrative': '1063000000',
#    'researchAndDevelopment': '358000000',
#    'operatingExpenses': '1421000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '45000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '197000000',
#    'incomeBeforeTax': '3729000000',
#    'incomeTaxExpense': '1197000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '5105000000',
#    'comprehensiveIncomeNetOfTax': '2628000000',
#    'ebit': '3684000000',
#    'ebitda': '2390000000',
#    'netIncome': '2532000000'},
#   {'fiscalDateEnding': '2009-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '3983000000',
#    'totalRevenue': '8337000000',
#    'costOfRevenue': '5314000000',
#    'costofGoodsAndServicesSold': '5751000000',
#    'operatingIncome': '2632000000',
#    'sellingGeneralAndAdministrative': '1010000000',
#    'researchAndDevelopment': '341000000',
#    'operatingExpenses': '1351000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '236000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '60000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '176000000',
#    'incomeBeforeTax': '2692000000',
#    'incomeTaxExpense': '864000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '1229000000',
#    'comprehensiveIncomeNetOfTax': '1900000000',
#    'ebit': '2632000000',
#    'ebitda': '1672000000',
#    'netIncome': '1828000000'},
#   {'fiscalDateEnding': '2009-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '3627000000',
#    'totalRevenue': '8163000000',
#    'costOfRevenue': '5192000000',
#    'costofGoodsAndServicesSold': '5457000000',
#    'operatingIncome': '2323000000',
#    'sellingGeneralAndAdministrative': '985000000',
#    'researchAndDevelopment': '319000000',
#    'operatingExpenses': '1304000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '63000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '172000000',
#    'incomeBeforeTax': '2386000000',
#    'incomeTaxExpense': '766000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': 'None',
#    'comprehensiveIncomeNetOfTax': 'None',
#    'ebit': '2323000000',
#    'ebitda': '1839000000',
#    'netIncome': '1620000000'},
#   {'fiscalDateEnding': '2008-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '4507000000',
#    'totalRevenue': '10167000000',
#    'costOfRevenue': '6635000000',
#    'costofGoodsAndServicesSold': '7373000000',
#    'operatingIncome': '3101000000',
#    'sellingGeneralAndAdministrative': '1091000000',
#    'researchAndDevelopment': '315000000',
#    'operatingExpenses': '1406000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '158000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '158000000',
#    'incomeBeforeTax': '3259000000',
#    'incomeTaxExpense': '1004000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': 'None',
#    'comprehensiveIncomeNetOfTax': 'None',
#    'ebit': '3101000000',
#    'ebitda': '2284000000',
#    'netIncome': '2255000000'},
#   {'fiscalDateEnding': '2008-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '4791000000',
#    'totalRevenue': '7895000000',
#    'costOfRevenue': '5156000000',
#    'costofGoodsAndServicesSold': '8116000000',
#    'operatingIncome': '3494000000',
#    'sellingGeneralAndAdministrative': '999000000',
#    'researchAndDevelopment': '298000000',
#    'operatingExpenses': '1297000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '140000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '134000000',
#    'incomeBeforeTax': '3634000000',
#    'incomeTaxExpense': '1213000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': 'None',
#    'comprehensiveIncomeNetOfTax': 'None',
#    'ebit': '3494000000',
#    'ebitda': '1576000000',
#    'netIncome': '2421000000'},
#   {'fiscalDateEnding': '2008-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '2600000000',
#    'totalRevenue': '7464000000',
#    'costOfRevenue': '4864000000',
#    'costofGoodsAndServicesSold': '4864000000',
#    'operatingIncome': '1392000000',
#    'sellingGeneralAndAdministrative': '916000000',
#    'researchAndDevelopment': '292000000',
#    'operatingExpenses': '1208000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': '118000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '117000000',
#    'incomeBeforeTax': '1510000000',
#    'incomeTaxExpense': '438000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': 'None',
#    'comprehensiveIncomeNetOfTax': 'None',
#    'ebit': '1392000000',
#    'ebitda': '1509000000',
#    'netIncome': '1072000000'}]}

# %%
print(json.dumps(t, indent=4))
# Out:
# {
#     "symbol": "AAPL",
#     "annualReports": [
#         {
#             "fiscalDateEnding": "2023-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "169148000000",
#             "totalRevenue": "379352000000",
#             "costOfRevenue": "239069000000",
#             "costofGoodsAndServicesSold": "214137000000",
#             "operatingIncome": "114301000000",
#             "sellingGeneralAndAdministrative": "24932000000",
#             "researchAndDevelopment": "29915000000",
#             "operatingExpenses": "54847000000",
#             "investmentIncomeNet": "3750000000",
#             "netInterestIncome": "-3933000000",
#             "interestIncome": "183000000",
#             "interestExpense": "3933000000",
#             "nonInterestIncome": "383285000000",
#             "otherNonOperatingIncome": "-382000000",
#             "depreciation": "8500000000",
#             "depreciationAndAmortization": "11519000000",
#             "incomeBeforeTax": "113736000000",
#             "incomeTaxExpense": "16741000000",
#             "interestAndDebtExpense": "3933000000",
#             "netIncomeFromContinuingOperations": "96995000000",
#             "comprehensiveIncomeNetOfTax": "96652000000",
#             "ebit": "117669000000",
#             "ebitda": "125820000000",
#             "netIncome": "96995000000"
#         },
#         {
#             "fiscalDateEnding": "2022-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "170782000000",
#             "totalRevenue": "391397000000",
#             "costOfRevenue": "248640000000",
#             "costofGoodsAndServicesSold": "223546000000",
#             "operatingIncome": "119437000000",
#             "sellingGeneralAndAdministrative": "25094000000",
#             "researchAndDevelopment": "26251000000",
#             "operatingExpenses": "51345000000",
#             "investmentIncomeNet": "2825000000",
#             "netInterestIncome": "-2931000000",
#             "interestIncome": "106000000",
#             "interestExpense": "2931000000",
#             "nonInterestIncome": "394328000000",
#             "otherNonOperatingIncome": "-228000000",
#             "depreciation": "8700000000",
#             "depreciationAndAmortization": "11104000000",
#             "incomeBeforeTax": "119103000000",
#             "incomeTaxExpense": "19300000000",
#             "interestAndDebtExpense": "2931000000",
#             "netIncomeFromContinuingOperations": "99803000000",
#             "comprehensiveIncomeNetOfTax": "88531000000",
#             "ebit": "122034000000",
#             "ebitda": "130541000000",
#             "netIncome": "99803000000"
#         },
#         {
#             "fiscalDateEnding": "2021-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "152836000000",
#             "totalRevenue": "363172000000",
#             "costOfRevenue": "234954000000",
#             "costofGoodsAndServicesSold": "212981000000",
#             "operatingIncome": "108949000000",
#             "sellingGeneralAndAdministrative": "21973000000",
#             "researchAndDevelopment": "21914000000",
#             "operatingExpenses": "43887000000",
#             "investmentIncomeNet": "2843000000",
#             "netInterestIncome": "-2645000000",
#             "interestIncome": "2843000000",
#             "interestExpense": "2645000000",
#             "nonInterestIncome": "365817000000",
#             "otherNonOperatingIncome": "60000000",
#             "depreciation": "9500000000",
#             "depreciationAndAmortization": "11284000000",
#             "incomeBeforeTax": "109207000000",
#             "incomeTaxExpense": "14527000000",
#             "interestAndDebtExpense": "2645000000",
#             "netIncomeFromContinuingOperations": "94680000000",
#             "comprehensiveIncomeNetOfTax": "95249000000",
#             "ebit": "111852000000",
#             "ebitda": "120233000000",
#             "netIncome": "94680000000"
#         },
#         {
#             "fiscalDateEnding": "2020-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "104956000000",
#             "totalRevenue": "271642000000",
#             "costOfRevenue": "189475000000",
#             "costofGoodsAndServicesSold": "169559000000",
#             "operatingIncome": "66288000000",
#             "sellingGeneralAndAdministrative": "19916000000",
#             "researchAndDevelopment": "18752000000",
#             "operatingExpenses": "38668000000",
#             "investmentIncomeNet": "3763000000",
#             "netInterestIncome": "-2873000000",
#             "interestIncome": "3763000000",
#             "interestExpense": "2873000000",
#             "nonInterestIncome": "274515000000",
#             "otherNonOperatingIncome": "-87000000",
#             "depreciation": "9700000000",
#             "depreciationAndAmortization": "11056000000",
#             "incomeBeforeTax": "67091000000",
#             "incomeTaxExpense": "9680000000",
#             "interestAndDebtExpense": "2873000000",
#             "netIncomeFromContinuingOperations": "57411000000",
#             "comprehensiveIncomeNetOfTax": "57453000000",
#             "ebit": "69964000000",
#             "ebitda": "77344000000",
#             "netIncome": "57411000000"
#         },
#         {
#             "fiscalDateEnding": "2019-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "98392000000",
#             "totalRevenue": "256598000000",
#             "costOfRevenue": "180027000000",
#             "costofGoodsAndServicesSold": "161782000000",
#             "operatingIncome": "63930000000",
#             "sellingGeneralAndAdministrative": "18245000000",
#             "researchAndDevelopment": "16217000000",
#             "operatingExpenses": "34462000000",
#             "investmentIncomeNet": "4961000000",
#             "netInterestIncome": "-3576000000",
#             "interestIncome": "4961000000",
#             "interestExpense": "3576000000",
#             "nonInterestIncome": "260174000000",
#             "otherNonOperatingIncome": "422000000",
#             "depreciation": "11300000000",
#             "depreciationAndAmortization": "12547000000",
#             "incomeBeforeTax": "65737000000",
#             "incomeTaxExpense": "10481000000",
#             "interestAndDebtExpense": "3576000000",
#             "netIncomeFromContinuingOperations": "55256000000",
#             "comprehensiveIncomeNetOfTax": "58037000000",
#             "ebit": "69313000000",
#             "ebitda": "76477000000",
#             "netIncome": "55256000000"
#         },
#         {
#             "fiscalDateEnding": "2018-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "101839000000",
#             "totalRevenue": "265595000000",
#             "costOfRevenue": "163756000000",
#             "costofGoodsAndServicesSold": "163756000000",
#             "operatingIncome": "70898000000",
#             "sellingGeneralAndAdministrative": "16705000000",
#             "researchAndDevelopment": "14236000000",
#             "operatingExpenses": "30941000000",
#             "investmentIncomeNet": "5686000000",
#             "netInterestIncome": "-3240000000",
#             "interestIncome": "5686000000",
#             "interestExpense": "3240000000",
#             "nonInterestIncome": "265595000000",
#             "otherNonOperatingIncome": "-441000000",
#             "depreciation": "9300000000",
#             "depreciationAndAmortization": "10903000000",
#             "incomeBeforeTax": "72903000000",
#             "incomeTaxExpense": "13372000000",
#             "interestAndDebtExpense": "3240000000",
#             "netIncomeFromContinuingOperations": "59531000000",
#             "comprehensiveIncomeNetOfTax": "56505000000",
#             "ebit": "76143000000",
#             "ebitda": "81801000000",
#             "netIncome": "59531000000"
#         },
#         {
#             "fiscalDateEnding": "2017-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "88186000000",
#             "totalRevenue": "229234000000",
#             "costOfRevenue": "141048000000",
#             "costofGoodsAndServicesSold": "141048000000",
#             "operatingIncome": "61344000000",
#             "sellingGeneralAndAdministrative": "15261000000",
#             "researchAndDevelopment": "11581000000",
#             "operatingExpenses": "26842000000",
#             "investmentIncomeNet": "5201000000",
#             "netInterestIncome": "-2323000000",
#             "interestIncome": "5201000000",
#             "interestExpense": "2323000000",
#             "nonInterestIncome": "229234000000",
#             "otherNonOperatingIncome": "-133000000",
#             "depreciation": "8200000000",
#             "depreciationAndAmortization": "1200000000",
#             "incomeBeforeTax": "64089000000",
#             "incomeTaxExpense": "15738000000",
#             "interestAndDebtExpense": "2323000000",
#             "netIncomeFromContinuingOperations": "48351000000",
#             "comprehensiveIncomeNetOfTax": "47567000000",
#             "ebit": "66412000000",
#             "ebitda": "67612000000",
#             "netIncome": "48351000000"
#         },
#         {
#             "fiscalDateEnding": "2016-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "84263000000",
#             "totalRevenue": "215639000000",
#             "costOfRevenue": "131376000000",
#             "costofGoodsAndServicesSold": "131376000000",
#             "operatingIncome": "60024000000",
#             "sellingGeneralAndAdministrative": "14194000000",
#             "researchAndDevelopment": "10045000000",
#             "operatingExpenses": "24239000000",
#             "investmentIncomeNet": "3999000000",
#             "netInterestIncome": "-1456000000",
#             "interestIncome": "3999000000",
#             "interestExpense": "1456000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-1195000000",
#             "depreciation": "8300000000",
#             "depreciationAndAmortization": "8300000000",
#             "incomeBeforeTax": "61372000000",
#             "incomeTaxExpense": "15685000000",
#             "interestAndDebtExpense": "1456000000",
#             "netIncomeFromContinuingOperations": "45687000000",
#             "comprehensiveIncomeNetOfTax": "46666000000",
#             "ebit": "62828000000",
#             "ebitda": "71128000000",
#             "netIncome": "45687000000"
#         },
#         {
#             "fiscalDateEnding": "2015-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "93626000000",
#             "totalRevenue": "232982000000",
#             "costOfRevenue": "163618000000",
#             "costofGoodsAndServicesSold": "140089000000",
#             "operatingIncome": "71230000000",
#             "sellingGeneralAndAdministrative": "14329000000",
#             "researchAndDevelopment": "8067000000",
#             "operatingExpenses": "22396000000",
#             "investmentIncomeNet": "2921000000",
#             "netInterestIncome": "-733000000",
#             "interestIncome": "None",
#             "interestExpense": "733000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-903000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "9200000000",
#             "incomeBeforeTax": "72515000000",
#             "incomeTaxExpense": "19121000000",
#             "interestAndDebtExpense": "733000000",
#             "netIncomeFromContinuingOperations": "53394000000",
#             "comprehensiveIncomeNetOfTax": "51967000000",
#             "ebit": "73248000000",
#             "ebitda": "82448000000",
#             "netIncome": "53394000000"
#         },
#         {
#             "fiscalDateEnding": "2014-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "70537000000",
#             "totalRevenue": "182411000000",
#             "costOfRevenue": "131151000000",
#             "costofGoodsAndServicesSold": "112258000000",
#             "operatingIncome": "52503000000",
#             "sellingGeneralAndAdministrative": "11993000000",
#             "researchAndDevelopment": "6041000000",
#             "operatingExpenses": "18034000000",
#             "investmentIncomeNet": "1795000000",
#             "netInterestIncome": "-384000000",
#             "interestIncome": "None",
#             "interestExpense": "384000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-431000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "6900000000",
#             "incomeBeforeTax": "53483000000",
#             "incomeTaxExpense": "13973000000",
#             "interestAndDebtExpense": "384000000",
#             "netIncomeFromContinuingOperations": "39510000000",
#             "comprehensiveIncomeNetOfTax": "41063000000",
#             "ebit": "53867000000",
#             "ebitda": "60767000000",
#             "netIncome": "39510000000"
#         },
#         {
#             "fiscalDateEnding": "2013-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "64304000000",
#             "totalRevenue": "170774000000",
#             "costOfRevenue": "123236000000",
#             "costofGoodsAndServicesSold": "106606000000",
#             "operatingIncome": "48999000000",
#             "sellingGeneralAndAdministrative": "10830000000",
#             "researchAndDevelopment": "4475000000",
#             "operatingExpenses": "15305000000",
#             "investmentIncomeNet": "1616000000",
#             "netInterestIncome": "-136000000",
#             "interestIncome": "None",
#             "interestExpense": "136000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-324000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "5800000000",
#             "incomeBeforeTax": "50155000000",
#             "incomeTaxExpense": "13118000000",
#             "interestAndDebtExpense": "136000000",
#             "netIncomeFromContinuingOperations": "37037000000",
#             "comprehensiveIncomeNetOfTax": "36067000000",
#             "ebit": "50291000000",
#             "ebitda": "56091000000",
#             "netIncome": "37037000000"
#         },
#         {
#             "fiscalDateEnding": "2012-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "68662000000",
#             "totalRevenue": "156508000000",
#             "costOfRevenue": "100486000000",
#             "costofGoodsAndServicesSold": "87846000000",
#             "operatingIncome": "55241000000",
#             "sellingGeneralAndAdministrative": "10040000000",
#             "researchAndDevelopment": "3381000000",
#             "operatingExpenses": "13421000000",
#             "investmentIncomeNet": "1088000000",
#             "netInterestIncome": "0",
#             "interestIncome": "None",
#             "interestExpense": "0",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-566000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2600000000",
#             "incomeBeforeTax": "55763000000",
#             "incomeTaxExpense": "14030000000",
#             "interestAndDebtExpense": "0",
#             "netIncomeFromContinuingOperations": "41733000000",
#             "comprehensiveIncomeNetOfTax": "41789000000",
#             "ebit": "55763000000",
#             "ebitda": "58363000000",
#             "netIncome": "41733000000"
#         },
#         {
#             "fiscalDateEnding": "2011-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "43818000000",
#             "totalRevenue": "108249000000",
#             "costOfRevenue": "73630000000",
#             "costofGoodsAndServicesSold": "64431000000",
#             "operatingIncome": "33790000000",
#             "sellingGeneralAndAdministrative": "7599000000",
#             "researchAndDevelopment": "2429000000",
#             "operatingExpenses": "10028000000",
#             "investmentIncomeNet": "519000000",
#             "netInterestIncome": "0",
#             "interestIncome": "None",
#             "interestExpense": "0",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "-104000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "1600000000",
#             "incomeBeforeTax": "34205000000",
#             "incomeTaxExpense": "8283000000",
#             "interestAndDebtExpense": "0",
#             "netIncomeFromContinuingOperations": "25922000000",
#             "comprehensiveIncomeNetOfTax": "26411000000",
#             "ebit": "34205000000",
#             "ebitda": "35805000000",
#             "netIncome": "25922000000"
#         },
#         {
#             "fiscalDateEnding": "2010-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "25684000000",
#             "totalRevenue": "65225000000",
#             "costOfRevenue": "45873000000",
#             "costofGoodsAndServicesSold": "39541000000",
#             "operatingIncome": "18385000000",
#             "sellingGeneralAndAdministrative": "5517000000",
#             "researchAndDevelopment": "1782000000",
#             "operatingExpenses": "7299000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "155000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "155000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "815000000",
#             "incomeBeforeTax": "18540000000",
#             "incomeTaxExpense": "4527000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "14013000000",
#             "comprehensiveIncomeNetOfTax": "13890000000",
#             "ebit": "18385000000",
#             "ebitda": "19200000000",
#             "netIncome": "14013000000"
#         },
#         {
#             "fiscalDateEnding": "2009-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "17222000000",
#             "totalRevenue": "42905000000",
#             "costOfRevenue": "29832000000",
#             "costofGoodsAndServicesSold": "25683000000",
#             "operatingIncome": "11740000000",
#             "sellingGeneralAndAdministrative": "4149000000",
#             "researchAndDevelopment": "1333000000",
#             "operatingExpenses": "5482000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "326000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "326000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "606000000",
#             "incomeBeforeTax": "12066000000",
#             "incomeTaxExpense": "3831000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "8235000000",
#             "comprehensiveIncomeNetOfTax": "8321000000",
#             "ebit": "11740000000",
#             "ebitda": "12346000000",
#             "netIncome": "8235000000"
#         }
#     ],
#     "quarterlyReports": [
#         {
#             "fiscalDateEnding": "2023-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "54855000000",
#             "totalRevenue": "119575000000",
#             "costOfRevenue": "71506000000",
#             "costofGoodsAndServicesSold": "64720000000",
#             "operatingIncome": "40373000000",
#             "sellingGeneralAndAdministrative": "6786000000",
#             "researchAndDevelopment": "7696000000",
#             "operatingExpenses": "14482000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "None",
#             "nonInterestIncome": "119575000000",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2848000000",
#             "incomeBeforeTax": "40323000000",
#             "incomeTaxExpense": "6407000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "33916000000",
#             "comprehensiveIncomeNetOfTax": "35990000000",
#             "ebit": "40373000000",
#             "ebitda": "43221000000",
#             "netIncome": "33916000000"
#         },
#         {
#             "fiscalDateEnding": "2023-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "40427000000",
#             "totalRevenue": "88496000000",
#             "costOfRevenue": "55222000000",
#             "costofGoodsAndServicesSold": "49071000000",
#             "operatingIncome": "26969000000",
#             "sellingGeneralAndAdministrative": "6151000000",
#             "researchAndDevelopment": "7307000000",
#             "operatingExpenses": "13458000000",
#             "investmentIncomeNet": "984000000",
#             "netInterestIncome": "-1002000000",
#             "interestIncome": "18000000",
#             "interestExpense": "1002000000",
#             "nonInterestIncome": "89498000000",
#             "otherNonOperatingIncome": "47000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2653000000",
#             "incomeBeforeTax": "26998000000",
#             "incomeTaxExpense": "4042000000",
#             "interestAndDebtExpense": "1002000000",
#             "netIncomeFromContinuingOperations": "22956000000",
#             "comprehensiveIncomeNetOfTax": "23305000000",
#             "ebit": "28000000000",
#             "ebitda": "29622000000",
#             "netIncome": "22956000000"
#         },
#         {
#             "fiscalDateEnding": "2023-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "36413000000",
#             "totalRevenue": "80799000000",
#             "costOfRevenue": "51357000000",
#             "costofGoodsAndServicesSold": "45384000000",
#             "operatingIncome": "22998000000",
#             "sellingGeneralAndAdministrative": "5973000000",
#             "researchAndDevelopment": "7442000000",
#             "operatingExpenses": "13415000000",
#             "investmentIncomeNet": "980000000",
#             "netInterestIncome": "-998000000",
#             "interestIncome": "18000000",
#             "interestExpense": "998000000",
#             "nonInterestIncome": "81797000000",
#             "otherNonOperatingIncome": "-247000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "3052000000",
#             "incomeBeforeTax": "22733000000",
#             "incomeTaxExpense": "2852000000",
#             "interestAndDebtExpense": "998000000",
#             "netIncomeFromContinuingOperations": "19881000000",
#             "comprehensiveIncomeNetOfTax": "19826000000",
#             "ebit": "23731000000",
#             "ebitda": "26050000000",
#             "netIncome": "19881000000"
#         },
#         {
#             "fiscalDateEnding": "2023-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "41976000000",
#             "totalRevenue": "94836000000",
#             "costOfRevenue": "52860000000",
#             "costofGoodsAndServicesSold": "52860000000",
#             "operatingIncome": "28318000000",
#             "sellingGeneralAndAdministrative": "6201000000",
#             "researchAndDevelopment": "7457000000",
#             "operatingExpenses": "13658000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "-12000000",
#             "interestIncome": "12000000",
#             "interestExpense": "930000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "76000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2898000000",
#             "incomeBeforeTax": "28382000000",
#             "incomeTaxExpense": "4222000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "24160000000",
#             "comprehensiveIncomeNetOfTax": "25326000000",
#             "ebit": "29312000000",
#             "ebitda": "31216000000",
#             "netIncome": "24160000000"
#         },
#         {
#             "fiscalDateEnding": "2022-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "50332000000",
#             "totalRevenue": "116151000000",
#             "costOfRevenue": "73429000000",
#             "costofGoodsAndServicesSold": "66822000000",
#             "operatingIncome": "36016000000",
#             "sellingGeneralAndAdministrative": "6607000000",
#             "researchAndDevelopment": "7709000000",
#             "operatingExpenses": "14316000000",
#             "investmentIncomeNet": "868000000",
#             "netInterestIncome": "-1003000000",
#             "interestIncome": "135000000",
#             "interestExpense": "1003000000",
#             "nonInterestIncome": "117154000000",
#             "otherNonOperatingIncome": "-258000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2916000000",
#             "incomeBeforeTax": "35623000000",
#             "incomeTaxExpense": "5625000000",
#             "interestAndDebtExpense": "1003000000",
#             "netIncomeFromContinuingOperations": "29998000000",
#             "comprehensiveIncomeNetOfTax": "28195000000",
#             "ebit": "36626000000",
#             "ebitda": "38932000000",
#             "netIncome": "29998000000"
#         },
#         {
#             "fiscalDateEnding": "2022-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "38095000000",
#             "totalRevenue": "89319000000",
#             "costOfRevenue": "58491000000",
#             "costofGoodsAndServicesSold": "52051000000",
#             "operatingIncome": "24894000000",
#             "sellingGeneralAndAdministrative": "6440000000",
#             "researchAndDevelopment": "6761000000",
#             "operatingExpenses": "13201000000",
#             "investmentIncomeNet": "753000000",
#             "netInterestIncome": "-827000000",
#             "interestIncome": "74000000",
#             "interestExpense": "827000000",
#             "nonInterestIncome": "90146000000",
#             "otherNonOperatingIncome": "-163000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2865000000",
#             "incomeBeforeTax": "24657000000",
#             "incomeTaxExpense": "3936000000",
#             "interestAndDebtExpense": "827000000",
#             "netIncomeFromContinuingOperations": "20721000000",
#             "comprehensiveIncomeNetOfTax": "18909000000",
#             "ebit": "25484000000",
#             "ebitda": "27759000000",
#             "netIncome": "20721000000"
#         },
#         {
#             "fiscalDateEnding": "2022-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "35885000000",
#             "totalRevenue": "82240000000",
#             "costOfRevenue": "53086000000",
#             "costofGoodsAndServicesSold": "47074000000",
#             "operatingIncome": "23076000000",
#             "sellingGeneralAndAdministrative": "6012000000",
#             "researchAndDevelopment": "6797000000",
#             "operatingExpenses": "12809000000",
#             "investmentIncomeNet": "722000000",
#             "netInterestIncome": "-719000000",
#             "interestIncome": "722000000",
#             "interestExpense": "719000000",
#             "nonInterestIncome": "82959000000",
#             "otherNonOperatingIncome": "-13000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2805000000",
#             "incomeBeforeTax": "23066000000",
#             "incomeTaxExpense": "3624000000",
#             "interestAndDebtExpense": "719000000",
#             "netIncomeFromContinuingOperations": "19442000000",
#             "comprehensiveIncomeNetOfTax": "16639000000",
#             "ebit": "23785000000",
#             "ebitda": "25881000000",
#             "netIncome": "19442000000"
#         },
#         {
#             "fiscalDateEnding": "2022-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "42559000000",
#             "totalRevenue": "96587000000",
#             "costOfRevenue": "60912000000",
#             "costofGoodsAndServicesSold": "54719000000",
#             "operatingIncome": "29979000000",
#             "sellingGeneralAndAdministrative": "6193000000",
#             "researchAndDevelopment": "6387000000",
#             "operatingExpenses": "12580000000",
#             "investmentIncomeNet": "700000000",
#             "netInterestIncome": "-691000000",
#             "interestIncome": "700000000",
#             "interestExpense": "691000000",
#             "nonInterestIncome": "97278000000",
#             "otherNonOperatingIncome": "151000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2737000000",
#             "incomeBeforeTax": "30139000000",
#             "incomeTaxExpense": "5129000000",
#             "interestAndDebtExpense": "691000000",
#             "netIncomeFromContinuingOperations": "25010000000",
#             "comprehensiveIncomeNetOfTax": "19443000000",
#             "ebit": "30830000000",
#             "ebitda": "32716000000",
#             "netIncome": "25010000000"
#         },
#         {
#             "fiscalDateEnding": "2021-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "54243000000",
#             "totalRevenue": "123251000000",
#             "costOfRevenue": "76151000000",
#             "costofGoodsAndServicesSold": "69702000000",
#             "operatingIncome": "41488000000",
#             "sellingGeneralAndAdministrative": "6449000000",
#             "researchAndDevelopment": "6306000000",
#             "operatingExpenses": "12755000000",
#             "investmentIncomeNet": "650000000",
#             "netInterestIncome": "-694000000",
#             "interestIncome": "650000000",
#             "interestExpense": "694000000",
#             "nonInterestIncome": "123945000000",
#             "otherNonOperatingIncome": "-203000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2697000000",
#             "incomeBeforeTax": "41241000000",
#             "incomeTaxExpense": "6611000000",
#             "interestAndDebtExpense": "694000000",
#             "netIncomeFromContinuingOperations": "34630000000",
#             "comprehensiveIncomeNetOfTax": "33540000000",
#             "ebit": "41935000000",
#             "ebitda": "44185000000",
#             "netIncome": "34630000000"
#         },
#         {
#             "fiscalDateEnding": "2021-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "35174000000",
#             "totalRevenue": "82688000000",
#             "costOfRevenue": "53802000000",
#             "costofGoodsAndServicesSold": "48186000000",
#             "operatingIncome": "23786000000",
#             "sellingGeneralAndAdministrative": "5616000000",
#             "researchAndDevelopment": "5772000000",
#             "operatingExpenses": "11388000000",
#             "investmentIncomeNet": "659000000",
#             "netInterestIncome": "-672000000",
#             "interestIncome": "659000000",
#             "interestExpense": "672000000",
#             "nonInterestIncome": "83360000000",
#             "otherNonOperatingIncome": "-525000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2989000000",
#             "incomeBeforeTax": "23248000000",
#             "incomeTaxExpense": "2697000000",
#             "interestAndDebtExpense": "672000000",
#             "netIncomeFromContinuingOperations": "20551000000",
#             "comprehensiveIncomeNetOfTax": "20656000000",
#             "ebit": "23920000000",
#             "ebitda": "26775000000",
#             "netIncome": "20551000000"
#         },
#         {
#             "fiscalDateEnding": "2021-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "35255000000",
#             "totalRevenue": "80769000000",
#             "costOfRevenue": "51591000000",
#             "costofGoodsAndServicesSold": "46179000000",
#             "operatingIncome": "24126000000",
#             "sellingGeneralAndAdministrative": "5412000000",
#             "researchAndDevelopment": "5717000000",
#             "operatingExpenses": "11129000000",
#             "investmentIncomeNet": "719000000",
#             "netInterestIncome": "-665000000",
#             "interestIncome": "719000000",
#             "interestExpense": "665000000",
#             "nonInterestIncome": "81434000000",
#             "otherNonOperatingIncome": "189000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2832000000",
#             "incomeBeforeTax": "24369000000",
#             "incomeTaxExpense": "2625000000",
#             "interestAndDebtExpense": "665000000",
#             "netIncomeFromContinuingOperations": "21744000000",
#             "comprehensiveIncomeNetOfTax": "22088000000",
#             "ebit": "25034000000",
#             "ebitda": "26958000000",
#             "netIncome": "21744000000"
#         },
#         {
#             "fiscalDateEnding": "2021-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "38079000000",
#             "totalRevenue": "88914000000",
#             "costOfRevenue": "56819000000",
#             "costofGoodsAndServicesSold": "51505000000",
#             "operatingIncome": "27503000000",
#             "sellingGeneralAndAdministrative": "5314000000",
#             "researchAndDevelopment": "5262000000",
#             "operatingExpenses": "10576000000",
#             "investmentIncomeNet": "718000000",
#             "netInterestIncome": "-670000000",
#             "interestIncome": "718000000",
#             "interestExpense": "670000000",
#             "nonInterestIncome": "89584000000",
#             "otherNonOperatingIncome": "460000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2797000000",
#             "incomeBeforeTax": "28011000000",
#             "incomeTaxExpense": "4381000000",
#             "interestAndDebtExpense": "670000000",
#             "netIncomeFromContinuingOperations": "23630000000",
#             "comprehensiveIncomeNetOfTax": "23165000000",
#             "ebit": "28681000000",
#             "ebitda": "30300000000",
#             "netIncome": "23630000000"
#         },
#         {
#             "fiscalDateEnding": "2020-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "44328000000",
#             "totalRevenue": "110801000000",
#             "costOfRevenue": "72742000000",
#             "costofGoodsAndServicesSold": "67111000000",
#             "operatingIncome": "33534000000",
#             "sellingGeneralAndAdministrative": "5631000000",
#             "researchAndDevelopment": "5163000000",
#             "operatingExpenses": "10794000000",
#             "investmentIncomeNet": "747000000",
#             "netInterestIncome": "-638000000",
#             "interestIncome": "747000000",
#             "interestExpense": "638000000",
#             "nonInterestIncome": "111439000000",
#             "otherNonOperatingIncome": "-64000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2666000000",
#             "incomeBeforeTax": "33579000000",
#             "incomeTaxExpense": "4824000000",
#             "interestAndDebtExpense": "638000000",
#             "netIncomeFromContinuingOperations": "28755000000",
#             "comprehensiveIncomeNetOfTax": "29340000000",
#             "ebit": "34217000000",
#             "ebitda": "36200000000",
#             "netIncome": "28755000000"
#         },
#         {
#             "fiscalDateEnding": "2020-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "24689000000",
#             "totalRevenue": "64698000000",
#             "costOfRevenue": "44945000000",
#             "costofGoodsAndServicesSold": "40009000000",
#             "operatingIncome": "14775000000",
#             "sellingGeneralAndAdministrative": "4936000000",
#             "researchAndDevelopment": "4978000000",
#             "operatingExpenses": "9914000000",
#             "investmentIncomeNet": "768000000",
#             "netInterestIncome": "-634000000",
#             "interestIncome": "134000000",
#             "interestExpense": "634000000",
#             "nonInterestIncome": "64698000000",
#             "otherNonOperatingIncome": "-8000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2702000000",
#             "incomeBeforeTax": "14901000000",
#             "incomeTaxExpense": "2228000000",
#             "interestAndDebtExpense": "634000000",
#             "netIncomeFromContinuingOperations": "24689000000",
#             "comprehensiveIncomeNetOfTax": "12817000000",
#             "ebit": "15535000000",
#             "ebitda": "17477000000",
#             "netIncome": "12673000000"
#         },
#         {
#             "fiscalDateEnding": "2020-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "22680000000",
#             "totalRevenue": "58988000000",
#             "costOfRevenue": "41836000000",
#             "costofGoodsAndServicesSold": "37005000000",
#             "operatingIncome": "13091000000",
#             "sellingGeneralAndAdministrative": "4831000000",
#             "researchAndDevelopment": "4758000000",
#             "operatingExpenses": "9589000000",
#             "investmentIncomeNet": "901000000",
#             "netInterestIncome": "-697000000",
#             "interestIncome": "901000000",
#             "interestExpense": "697000000",
#             "nonInterestIncome": "59685000000",
#             "otherNonOperatingIncome": "-158000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2752000000",
#             "incomeBeforeTax": "13137000000",
#             "incomeTaxExpense": "1884000000",
#             "interestAndDebtExpense": "697000000",
#             "netIncomeFromContinuingOperations": "11253000000",
#             "comprehensiveIncomeNetOfTax": "13492000000",
#             "ebit": "13834000000",
#             "ebitda": "15843000000",
#             "netIncome": "11253000000"
#         },
#         {
#             "fiscalDateEnding": "2020-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "22370000000",
#             "totalRevenue": "57556000000",
#             "costOfRevenue": "40895000000",
#             "costofGoodsAndServicesSold": "35943000000",
#             "operatingIncome": "12853000000",
#             "sellingGeneralAndAdministrative": "4952000000",
#             "researchAndDevelopment": "4565000000",
#             "operatingExpenses": "9517000000",
#             "investmentIncomeNet": "1049000000",
#             "netInterestIncome": "-757000000",
#             "interestIncome": "1049000000",
#             "interestExpense": "757000000",
#             "nonInterestIncome": "58313000000",
#             "otherNonOperatingIncome": "-10000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2786000000",
#             "incomeBeforeTax": "13135000000",
#             "incomeTaxExpense": "1886000000",
#             "interestAndDebtExpense": "757000000",
#             "netIncomeFromContinuingOperations": "11249000000",
#             "comprehensiveIncomeNetOfTax": "8878000000",
#             "ebit": "13892000000",
#             "ebitda": "15639000000",
#             "netIncome": "11249000000"
#         },
#         {
#             "fiscalDateEnding": "2019-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "35217000000",
#             "totalRevenue": "91034000000",
#             "costOfRevenue": "61799000000",
#             "costofGoodsAndServicesSold": "56602000000",
#             "operatingIncome": "25569000000",
#             "sellingGeneralAndAdministrative": "5197000000",
#             "researchAndDevelopment": "4451000000",
#             "operatingExpenses": "9648000000",
#             "investmentIncomeNet": "1045000000",
#             "netInterestIncome": "-785000000",
#             "interestIncome": "1045000000",
#             "interestExpense": "785000000",
#             "nonInterestIncome": "91819000000",
#             "otherNonOperatingIncome": "89000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2816000000",
#             "incomeBeforeTax": "25918000000",
#             "incomeTaxExpense": "3682000000",
#             "interestAndDebtExpense": "785000000",
#             "netIncomeFromContinuingOperations": "22236000000",
#             "comprehensiveIncomeNetOfTax": "22266000000",
#             "ebit": "26703000000",
#             "ebitda": "28385000000",
#             "netIncome": "22236000000"
#         },
#         {
#             "fiscalDateEnding": "2019-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "24313000000",
#             "totalRevenue": "64040000000",
#             "costOfRevenue": "44305000000",
#             "costofGoodsAndServicesSold": "39727000000",
#             "operatingIncome": "15625000000",
#             "sellingGeneralAndAdministrative": "4578000000",
#             "researchAndDevelopment": "4110000000",
#             "operatingExpenses": "8688000000",
#             "investmentIncomeNet": "1106000000",
#             "netInterestIncome": "-810000000",
#             "interestIncome": "1106000000",
#             "interestExpense": "810000000",
#             "nonInterestIncome": "64040000000",
#             "otherNonOperatingIncome": "206000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "3179000000",
#             "incomeBeforeTax": "16127000000",
#             "incomeTaxExpense": "2441000000",
#             "interestAndDebtExpense": "810000000",
#             "netIncomeFromContinuingOperations": "24313000000",
#             "comprehensiveIncomeNetOfTax": "13741000000",
#             "ebit": "16937000000",
#             "ebitda": "18804000000",
#             "netIncome": "13686000000"
#         },
#         {
#             "fiscalDateEnding": "2019-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "20227000000",
#             "totalRevenue": "52943000000",
#             "costOfRevenue": "38008000000",
#             "costofGoodsAndServicesSold": "33582000000",
#             "operatingIncome": "11544000000",
#             "sellingGeneralAndAdministrative": "4426000000",
#             "researchAndDevelopment": "4257000000",
#             "operatingExpenses": "8683000000",
#             "investmentIncomeNet": "1190000000",
#             "netInterestIncome": "-866000000",
#             "interestIncome": "1190000000",
#             "interestExpense": "866000000",
#             "nonInterestIncome": "53809000000",
#             "otherNonOperatingIncome": "43000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2933000000",
#             "incomeBeforeTax": "11911000000",
#             "incomeTaxExpense": "1867000000",
#             "interestAndDebtExpense": "866000000",
#             "netIncomeFromContinuingOperations": "10044000000",
#             "comprehensiveIncomeNetOfTax": "10904000000",
#             "ebit": "12777000000",
#             "ebitda": "14477000000",
#             "netIncome": "10044000000"
#         },
#         {
#             "fiscalDateEnding": "2019-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "21821000000",
#             "totalRevenue": "57005000000",
#             "costOfRevenue": "40652000000",
#             "costofGoodsAndServicesSold": "36194000000",
#             "operatingIncome": "13415000000",
#             "sellingGeneralAndAdministrative": "4458000000",
#             "researchAndDevelopment": "3948000000",
#             "operatingExpenses": "8406000000",
#             "investmentIncomeNet": "1358000000",
#             "netInterestIncome": "-1010000000",
#             "interestIncome": "1358000000",
#             "interestExpense": "1010000000",
#             "nonInterestIncome": "58015000000",
#             "otherNonOperatingIncome": "30000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "3040000000",
#             "incomeBeforeTax": "13793000000",
#             "incomeTaxExpense": "2232000000",
#             "interestAndDebtExpense": "1010000000",
#             "netIncomeFromContinuingOperations": "11561000000",
#             "comprehensiveIncomeNetOfTax": "13650000000",
#             "ebit": "14803000000",
#             "ebitda": "16455000000",
#             "netIncome": "11561000000"
#         },
#         {
#             "fiscalDateEnding": "2018-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "32031000000",
#             "totalRevenue": "83420000000",
#             "costOfRevenue": "57062000000",
#             "costofGoodsAndServicesSold": "52279000000",
#             "operatingIncome": "23346000000",
#             "sellingGeneralAndAdministrative": "4783000000",
#             "researchAndDevelopment": "3902000000",
#             "operatingExpenses": "8685000000",
#             "investmentIncomeNet": "1307000000",
#             "netInterestIncome": "-890000000",
#             "interestIncome": "None",
#             "interestExpense": "890000000",
#             "nonInterestIncome": "84310000000",
#             "otherNonOperatingIncome": "143000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "3395000000",
#             "incomeBeforeTax": "23906000000",
#             "incomeTaxExpense": "3941000000",
#             "interestAndDebtExpense": "890000000",
#             "netIncomeFromContinuingOperations": "19965000000",
#             "comprehensiveIncomeNetOfTax": "19742000000",
#             "ebit": "24796000000",
#             "ebitda": "26741000000",
#             "netIncome": "19965000000"
#         },
#         {
#             "fiscalDateEnding": "2018-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "24084000000",
#             "totalRevenue": "62900000000",
#             "costOfRevenue": "38816000000",
#             "costofGoodsAndServicesSold": "38816000000",
#             "operatingIncome": "16118000000",
#             "sellingGeneralAndAdministrative": "4216000000",
#             "researchAndDevelopment": "3750000000",
#             "operatingExpenses": "7966000000",
#             "investmentIncomeNet": "1311000000",
#             "netInterestIncome": "-868000000",
#             "interestIncome": "None",
#             "interestExpense": "868000000",
#             "nonInterestIncome": "62900000000",
#             "otherNonOperatingIncome": "-140000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2754000000",
#             "incomeBeforeTax": "16421000000",
#             "incomeTaxExpense": "2296000000",
#             "interestAndDebtExpense": "868000000",
#             "netIncomeFromContinuingOperations": "24084000000",
#             "comprehensiveIncomeNetOfTax": "13782000000",
#             "ebit": "17289000000",
#             "ebitda": "18872000000",
#             "netIncome": "14125000000"
#         },
#         {
#             "fiscalDateEnding": "2018-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "20421000000",
#             "totalRevenue": "53265000000",
#             "costOfRevenue": "32844000000",
#             "costofGoodsAndServicesSold": "32844000000",
#             "operatingIncome": "12612000000",
#             "sellingGeneralAndAdministrative": "4108000000",
#             "researchAndDevelopment": "3701000000",
#             "operatingExpenses": "7809000000",
#             "investmentIncomeNet": "1418000000",
#             "netInterestIncome": "-846000000",
#             "interestIncome": "None",
#             "interestExpense": "846000000",
#             "nonInterestIncome": "53265000000",
#             "otherNonOperatingIncome": "100000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "2665000000",
#             "incomeBeforeTax": "13284000000",
#             "incomeTaxExpense": "1765000000",
#             "interestAndDebtExpense": "846000000",
#             "netIncomeFromContinuingOperations": "11519000000",
#             "comprehensiveIncomeNetOfTax": "11472000000",
#             "ebit": "14130000000",
#             "ebitda": "15277000000",
#             "netIncome": "11519000000"
#         },
#         {
#             "fiscalDateEnding": "2018-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "23422000000",
#             "totalRevenue": "61137000000",
#             "costOfRevenue": "37715000000",
#             "costofGoodsAndServicesSold": "37715000000",
#             "operatingIncome": "15894000000",
#             "sellingGeneralAndAdministrative": "4150000000",
#             "researchAndDevelopment": "3378000000",
# ...
#             "incomeTaxExpense": "2168000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "11380000000",
#             "comprehensiveIncomeNetOfTax": "6677000000",
#             "ebit": "8710000000",
#             "ebitda": "9253000000",
#             "netIncome": "6623000000"
#         },
#         {
#             "fiscalDateEnding": "2011-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "11922000000",
#             "totalRevenue": "28571000000",
#             "costOfRevenue": "18564000000",
#             "costofGoodsAndServicesSold": "16649000000",
#             "operatingIncome": "9379000000",
#             "sellingGeneralAndAdministrative": "1915000000",
#             "researchAndDevelopment": "628000000",
#             "operatingExpenses": "2543000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "172000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "172000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "481000000",
#             "incomeBeforeTax": "9551000000",
#             "incomeTaxExpense": "2243000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "7308000000",
#             "comprehensiveIncomeNetOfTax": "7571000000",
#             "ebit": "9379000000",
#             "ebitda": "9860000000",
#             "netIncome": "7308000000"
#         },
#         {
#             "fiscalDateEnding": "2011-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "10218000000",
#             "totalRevenue": "24708000000",
#             "costOfRevenue": "16212000000",
#             "costofGoodsAndServicesSold": "14449000000",
#             "operatingIncome": "7874000000",
#             "sellingGeneralAndAdministrative": "1763000000",
#             "researchAndDevelopment": "581000000",
#             "operatingExpenses": "2344000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "26000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "26000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "434000000",
#             "incomeBeforeTax": "7900000000",
#             "incomeTaxExpense": "1913000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "5987000000",
#             "comprehensiveIncomeNetOfTax": "5999000000",
#             "ebit": "7874000000",
#             "ebitda": "8308000000",
#             "netIncome": "5987000000"
#         },
#         {
#             "fiscalDateEnding": "2010-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "10298000000",
#             "totalRevenue": "26741000000",
#             "costOfRevenue": "18339000000",
#             "costofGoodsAndServicesSold": "16443000000",
#             "operatingIncome": "7827000000",
#             "sellingGeneralAndAdministrative": "1896000000",
#             "researchAndDevelopment": "575000000",
#             "operatingExpenses": "2471000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "136000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "136000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "356000000",
#             "incomeBeforeTax": "7963000000",
#             "incomeTaxExpense": "1959000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "6004000000",
#             "comprehensiveIncomeNetOfTax": "6164000000",
#             "ebit": "7827000000",
#             "ebitda": "8183000000",
#             "netIncome": "6004000000"
#         },
#         {
#             "fiscalDateEnding": "2010-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "7512000000",
#             "totalRevenue": "20343000000",
#             "costOfRevenue": "15217000000",
#             "costofGoodsAndServicesSold": "12831000000",
#             "operatingIncome": "5447000000",
#             "sellingGeneralAndAdministrative": "1571000000",
#             "researchAndDevelopment": "494000000",
#             "operatingExpenses": "2065000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "14000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "14000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "329000000",
#             "incomeBeforeTax": "5461000000",
#             "incomeTaxExpense": "1153000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "7512000000",
#             "comprehensiveIncomeNetOfTax": "4154000000",
#             "ebit": "5447000000",
#             "ebitda": "5776000000",
#             "netIncome": "4308000000"
#         },
#         {
#             "fiscalDateEnding": "2010-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "6136000000",
#             "totalRevenue": "15700000000",
#             "costOfRevenue": "11002000000",
#             "costofGoodsAndServicesSold": "9564000000",
#             "operatingIncome": "4234000000",
#             "sellingGeneralAndAdministrative": "1438000000",
#             "researchAndDevelopment": "464000000",
#             "operatingExpenses": "1902000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "58000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "58000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "273000000",
#             "incomeBeforeTax": "4292000000",
#             "incomeTaxExpense": "1039000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "3253000000",
#             "comprehensiveIncomeNetOfTax": "3236000000",
#             "ebit": "4234000000",
#             "ebitda": "4507000000",
#             "netIncome": "3253000000"
#         },
#         {
#             "fiscalDateEnding": "2010-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "5625000000",
#             "totalRevenue": "13499000000",
#             "costOfRevenue": "9094000000",
#             "costofGoodsAndServicesSold": "7874000000",
#             "operatingIncome": "3979000000",
#             "sellingGeneralAndAdministrative": "1220000000",
#             "researchAndDevelopment": "426000000",
#             "operatingExpenses": "1646000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "266000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "50000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "216000000",
#             "incomeBeforeTax": "4029000000",
#             "incomeTaxExpense": "955000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "3074000000",
#             "comprehensiveIncomeNetOfTax": "3088000000",
#             "ebit": "3979000000",
#             "ebitda": "3979000000",
#             "netIncome": "3074000000"
#         },
#         {
#             "fiscalDateEnding": "2009-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "6411000000",
#             "totalRevenue": "15683000000",
#             "costOfRevenue": "10560000000",
#             "costofGoodsAndServicesSold": "9272000000",
#             "operatingIncome": "4725000000",
#             "sellingGeneralAndAdministrative": "1288000000",
#             "researchAndDevelopment": "398000000",
#             "operatingExpenses": "1686000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "33000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "33000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "209000000",
#             "incomeBeforeTax": "4758000000",
#             "incomeTaxExpense": "1380000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "3378000000",
#             "comprehensiveIncomeNetOfTax": "3412000000",
#             "ebit": "4725000000",
#             "ebitda": "4934000000",
#             "netIncome": "3378000000"
#         },
#         {
#             "fiscalDateEnding": "2009-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "5105000000",
#             "totalRevenue": "12207000000",
#             "costOfRevenue": "7102000000",
#             "costofGoodsAndServicesSold": "7102000000",
#             "operatingIncome": "3684000000",
#             "sellingGeneralAndAdministrative": "1063000000",
#             "researchAndDevelopment": "358000000",
#             "operatingExpenses": "1421000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "45000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "197000000",
#             "incomeBeforeTax": "3729000000",
#             "incomeTaxExpense": "1197000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "5105000000",
#             "comprehensiveIncomeNetOfTax": "2628000000",
#             "ebit": "3684000000",
#             "ebitda": "2390000000",
#             "netIncome": "2532000000"
#         },
#         {
#             "fiscalDateEnding": "2009-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "3983000000",
#             "totalRevenue": "8337000000",
#             "costOfRevenue": "5314000000",
#             "costofGoodsAndServicesSold": "5751000000",
#             "operatingIncome": "2632000000",
#             "sellingGeneralAndAdministrative": "1010000000",
#             "researchAndDevelopment": "341000000",
#             "operatingExpenses": "1351000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "236000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "60000000",
#             "depreciation": "None",
#             "depreciationAndAmortization": "176000000",
#             "incomeBeforeTax": "2692000000",
#             "incomeTaxExpense": "864000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "1229000000",
#             "comprehensiveIncomeNetOfTax": "1900000000",
#             "ebit": "2632000000",
#             "ebitda": "1672000000",
#             "netIncome": "1828000000"
#         },
#         {
#             "fiscalDateEnding": "2009-03-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "3627000000",
#             "totalRevenue": "8163000000",
#             "costOfRevenue": "5192000000",
#             "costofGoodsAndServicesSold": "5457000000",
#             "operatingIncome": "2323000000",
#             "sellingGeneralAndAdministrative": "985000000",
#             "researchAndDevelopment": "319000000",
#             "operatingExpenses": "1304000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "63000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "172000000",
#             "incomeBeforeTax": "2386000000",
#             "incomeTaxExpense": "766000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "None",
#             "comprehensiveIncomeNetOfTax": "None",
#             "ebit": "2323000000",
#             "ebitda": "1839000000",
#             "netIncome": "1620000000"
#         },
#         {
#             "fiscalDateEnding": "2008-12-31",
#             "reportedCurrency": "USD",
#             "grossProfit": "4507000000",
#             "totalRevenue": "10167000000",
#             "costOfRevenue": "6635000000",
#             "costofGoodsAndServicesSold": "7373000000",
#             "operatingIncome": "3101000000",
#             "sellingGeneralAndAdministrative": "1091000000",
#             "researchAndDevelopment": "315000000",
#             "operatingExpenses": "1406000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "158000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "158000000",
#             "incomeBeforeTax": "3259000000",
#             "incomeTaxExpense": "1004000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "None",
#             "comprehensiveIncomeNetOfTax": "None",
#             "ebit": "3101000000",
#             "ebitda": "2284000000",
#             "netIncome": "2255000000"
#         },
#         {
#             "fiscalDateEnding": "2008-09-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "4791000000",
#             "totalRevenue": "7895000000",
#             "costOfRevenue": "5156000000",
#             "costofGoodsAndServicesSold": "8116000000",
#             "operatingIncome": "3494000000",
#             "sellingGeneralAndAdministrative": "999000000",
#             "researchAndDevelopment": "298000000",
#             "operatingExpenses": "1297000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "140000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "134000000",
#             "incomeBeforeTax": "3634000000",
#             "incomeTaxExpense": "1213000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "None",
#             "comprehensiveIncomeNetOfTax": "None",
#             "ebit": "3494000000",
#             "ebitda": "1576000000",
#             "netIncome": "2421000000"
#         },
#         {
#             "fiscalDateEnding": "2008-06-30",
#             "reportedCurrency": "USD",
#             "grossProfit": "2600000000",
#             "totalRevenue": "7464000000",
#             "costOfRevenue": "4864000000",
#             "costofGoodsAndServicesSold": "4864000000",
#             "operatingIncome": "1392000000",
#             "sellingGeneralAndAdministrative": "916000000",
#             "researchAndDevelopment": "292000000",
#             "operatingExpenses": "1208000000",
#             "investmentIncomeNet": "None",
#             "netInterestIncome": "None",
#             "interestIncome": "None",
#             "interestExpense": "118000000",
#             "nonInterestIncome": "None",
#             "otherNonOperatingIncome": "None",
#             "depreciation": "None",
#             "depreciationAndAmortization": "117000000",
#             "incomeBeforeTax": "1510000000",
#             "incomeTaxExpense": "438000000",
#             "interestAndDebtExpense": "None",
#             "netIncomeFromContinuingOperations": "None",
#             "comprehensiveIncomeNetOfTax": "None",
#             "ebit": "1392000000",
#             "ebitda": "1509000000",
#             "netIncome": "1072000000"
#         }
#     ]
# }

# %%
data

# %%
data = t.copy()

# %%
len(data)

data.keys()
# Out:
# dict_keys(['symbol', 'annualReports', 'quarterlyReports'])

# %%
ar = data["annualReports"][0]
ar.keys()
# Out:
# dict_keys(['fiscalDateEnding', 'reportedCurrency', 'grossProfit', 'totalRevenue', 'costOfRevenue', 'costofGoodsAndServicesSold', 'operatingIncome', 'sellingGeneralAndAdministrative', 'researchAndDevelopment', 'operatingExpenses', 'investmentIncomeNet', 'netInterestIncome', 'interestIncome', 'interestExpense', 'nonInterestIncome', 'otherNonOperatingIncome', 'depreciation', 'depreciationAndAmortization', 'incomeBeforeTax', 'incomeTaxExpense', 'interestAndDebtExpense', 'netIncomeFromContinuingOperations', 'comprehensiveIncomeNetOfTax', 'ebit', 'ebitda', 'netIncome'])

# %%
qr = data["quarterlyReports"][0]
print(qr.keys())

ar.keys() == qr.keys()
# Out:
# dict_keys(['fiscalDateEnding', 'reportedCurrency', 'grossProfit', 'totalRevenue', 'costOfRevenue', 'costofGoodsAndServicesSold', 'operatingIncome', 'sellingGeneralAndAdministrative', 'researchAndDevelopment', 'operatingExpenses', 'investmentIncomeNet', 'netInterestIncome', 'interestIncome', 'interestExpense', 'nonInterestIncome', 'otherNonOperatingIncome', 'depreciation', 'depreciationAndAmortization', 'incomeBeforeTax', 'incomeTaxExpense', 'interestAndDebtExpense', 'netIncomeFromContinuingOperations', 'comprehensiveIncomeNetOfTax', 'ebit', 'ebitda', 'netIncome'])
# True

# %%
annual_report_data = data["annualReports"]
date_data = [x["fiscalDateEnding"] for x in annual_report_data]
gross_profit = [x["grossProfit"] for x in annual_report_data]
total_revenue = [x["totalRevenue"] for x in annual_report_data]
cost_of_revenue = [x["costOfRevenue"] for x in annual_report_data]
cogs = [x["costofGoodsAndServicesSold"] for x in annual_report_data]
operating_income = [x["operatingIncome"] for x in annual_report_data]
net_investment_income = [x["investmentIncomeNet"] for x in annual_report_data]
net_interest_income = [x["netInterestIncome"] for x in annual_report_data]
interest_income = [x["interestIncome"] for x in annual_report_data]
interest_expense = [x["interestExpense"] for x in annual_report_data]
non_interest_income = [x["nonInterestIncome"] for x in annual_report_data]
other_non_operating_income = [x["otherNonOperatingIncome"] for x in annual_report_data]
depreciation = [x["depreciation"] for x in annual_report_data]
depreciation_amortization = [
    x["depreciationAndAmortization"] for x in annual_report_data
]
income_before_tax = [x["incomeBeforeTax"] for x in annual_report_data]
income_tax_expense = [x["incomeTaxExpense"] for x in annual_report_data]
interest_and_debt_expense = [x["interestAndDebtExpense"] for x in annual_report_data]
net_income_from_continuing_operations = [
    x["netIncomeFromContinuingOperations"] for x in annual_report_data
]
comprensive_income = [x["comprehensiveIncomeNetOfTax"] for x in annual_report_data]
ebit = [x["ebit"] for x in annual_report_data]
ebitda = [x["ebitda"] for x in annual_report_data]
net_income = [x["netIncome"] for x in annual_report_data]

# %%
def parse_partial_income_statement(data, report_type: str):
    """
    Parses the income statement data and returns a dictionary containing various financial metrics.

    Args:
        data (dict): The income statement data.
        report_type (str): The type of report to parse. Must be either "annual" or "quarterly".

    Returns:
        dict: A dictionary containing the following financial metrics:
            - date_data: List of fiscal dates.
            - gross_profit: List of gross profit values.
            - total_revenue: List of total revenue values.
            - cost_of_revenue: List of cost of revenue values.
            - cogs: List of cost of goods and services sold values.
            - operating_income: List of operating income values.
            - net_investment_income: List of net investment income values.
            - net_interest_income: List of net interest income values.
            - interest_income: List of interest income values.
            - interest_expense: List of interest expense values.
            - non_interest_income: List of non-interest income values.
            - other_non_operating_income: List of other non-operating income values.
            - depreciation: List of depreciation values.
            - depreciation_amortization: List of depreciation and amortization values.
            - income_before_tax: List of income before tax values.
            - income_tax_expense: List of income tax expense values.
            - interest_and_debt_expense: List of interest and debt expense values.
            - net_income_from_continuing_operations: List of net income from continuing operations values.
            - comprensive_income: List of comprehensive income values.
            - ebit: List of EBIT (Earnings Before Interest and Taxes) values.
            - ebitda: List of EBITDA (Earnings Before Interest, Taxes, Depreciation, and Amortization) values.
            - net_income: List of net income values.

    Raises:
        ValueError: If the report_type is not "annual" or "quarterly".
    """

    if report_type == "annual":
        report_data = data["annualReports"]
    elif report_type == "quarterly":
        report_data = data["quarterlyReports"]
    else:
        raise ValueError('report_type must be either "annual" or "quarterly"')

    date = [x["fiscalDateEnding"] for x in report_data]
    gross_profit = [x["grossProfit"] for x in report_data]
    total_revenue = [x["totalRevenue"] for x in report_data]
    cost_of_revenue = [x["costOfRevenue"] for x in report_data]
    cogs = [x["costofGoodsAndServicesSold"] for x in report_data]
    operating_income = [x["operatingIncome"] for x in report_data]
    net_investment_income = [x["investmentIncomeNet"] for x in report_data]
    net_interest_income = [x["netInterestIncome"] for x in report_data]
    interest_income = [x["interestIncome"] for x in report_data]
    interest_expense = [x["interestExpense"] for x in report_data]
    non_interest_income = [x["nonInterestIncome"] for x in report_data]
    other_non_operating_income = [x["otherNonOperatingIncome"] for x in report_data]
    depreciation = [x["depreciation"] for x in report_data]
    depreciation_amortization = [x["depreciationAndAmortization"] for x in report_data]
    income_before_tax = [x["incomeBeforeTax"] for x in report_data]
    income_tax_expense = [x["incomeTaxExpense"] for x in report_data]
    interest_and_debt_expense = [x["interestAndDebtExpense"] for x in report_data]
    net_income_from_continuing_operations = [
        x["netIncomeFromContinuingOperations"] for x in report_data
    ]
    comprehensive_income = [x["comprehensiveIncomeNetOfTax"] for x in report_data]
    ebit = [x["ebit"] for x in report_data]
    ebitda = [x["ebitda"] for x in report_data]
    net_income = [x["netIncome"] for x in report_data]

    result = pd.DataFrame(
        {
            "symbol": data["symbol"],
            "report_type": report_type,
            "date": date,
            "gross_profit": gross_profit,
            "total_revenue": total_revenue,
            "cost_of_revenue": cost_of_revenue,
            "cogs": cogs,
            "operating_income": operating_income,
            "net_investment_income": net_investment_income,
            "net_interest_income": net_interest_income,
            "interest_income": interest_income,
            "interest_expense": interest_expense,
            "non_interest_income": non_interest_income,
            "other_non_operating_income": other_non_operating_income,
            "depreciation": depreciation,
            "depreciation_amortization": depreciation_amortization,
            "income_before_tax": income_before_tax,
            "income_tax_expense": income_tax_expense,
            "interest_and_debt_expense": interest_and_debt_expense,
            "net_income_from_continuing_operations": net_income_from_continuing_operations,
            "comprehensive_income": comprehensive_income,
            "ebit": ebit,
            "ebitda": ebitda,
            "net_income": net_income,
        }
    )

    def str_none_to_none(value):
        if value in ["None", "none", ""]:
            return None
        else:
            return value

    for col in result.columns:
        if col in ("symbol", "report_type"):
            result[col] = result[col].astype("str")
        elif col == "date":
            result[col] = pd.to_datetime(result[col])
        else:
            result[col] = result[col].apply(str_none_to_none)
            result[col] = result[col].astype("float")

    return result


def parse_income_statement(data):
    annual = parse_partial_income_statement(data, "annual")
    quarterly = parse_partial_income_statement(data, "quarterly")
    return pd.concat([annual, quarterly])

# %%
# def parse_partial_income_statement(data, report_type: str):
#     """
#     Parses the income statement data and returns a DataFrame containing various financial metrics.

#     Args:
#         data (dict): The income statement data.
#         report_type (str): The type of report to parse. Must be either "annual" or "quarterly".

#     Returns:
#         pd.DataFrame: A DataFrame containing financial metrics with appropriate data types.
#     """

#     if report_type not in ['annual', 'quarterly']:
#         raise ValueError('report_type must be either "annual" or "quarterly"')

#     report_data = data['annualReports'] if report_type == 'annual' else data['quarterlyReports']

#     # Initialize an empty dictionary to store the parsed data
#     parsed_data = {
#         'date': [],
#         'gross_profit': [],
#         'total_revenue': [],
#         'cost_of_revenue': [],
#         'cogs': [],
#         'operating_income': [],
#         'net_investment_income': [],
#         'net_interest_income': [],
#         'interest_income': [],
#         'interest_expense': [],
#         'non_interest_income': [],
#         'other_non_operating_income': [],
#         'depreciation': [],
#         'depreciation_amortization': [],
#         'income_before_tax': [],
#         'income_tax_expense': [],
#         'interest_and_debt_expense': [],
#         'net_income_from_continuing_operations': [],
#         'comprehensive_income': [],
#         'ebit': [],
#         'ebitda': [],
#         'net_income': [],
#     }

#     # Iterate over each report and parse the data, converting to appropriate data types
#     for item in report_data:
#         parsed_data['date'].append(datetime.datetime.strptime(item['fiscalDateEnding'], '%Y-%m-%d').date())
#         for key in parsed_data.keys():
#             if key != 'date':  # We've already handled date conversion
#                 value = item[key] if key in item and item[key] not in [None, 'None', ''] else None
#                 parsed_data[key].append(float(value) if value is not None else None)

#     # Create a DataFrame using the parsed data
#     result = pd.DataFrame({
#         'symbol': data['symbol'],
#         'report_type': report_type,
#         **parsed_data
#     })

#     return result

# %%
# data = parse_alpha_vantage.fetch_data(
#     top_companies[0],
#     function='INCOME_STATEMENT',
#     api_key=api_key,
# )


# annual_report_data = parse_income_statement(data, 'annual')
# quarterly_report_data = parse_income_statement(data, 'quarterly')

# %%
def single_pull_and_parse(
    company: str,
    fetch_function: str,
    parse_function,
    api_key: None | str = None,
):
    """
    Fetches data for a given company using the specified fetch function,
    parses the data using the specified parse function, and returns the parsed data.

    Args:
        company (str): The name of the company to fetch data for.
        fetch_function (str): The name of the fetch function to use for fetching data.
        parse_function (function): The function to use for parsing the fetched data.
        api_key (str, optional): The API key to use for fetching data. Defaults to None.

    Returns:
        The parsed data obtained from the fetch and parse operations.
        Returns None if there was a problem during the fetch or parse operations.
    """
    try:
        data = parse_alpha_vantage.fetch_data(
            company, function=fetch_function, api_key=api_key
        )
        parsed_data = parse_function(data)
        return parsed_data
    except KeyError:
        print(f"{company} had a problem")
        return None

# %%
def pull_and_parse(
    companies: list[str],
    fetch_function: str,
    parse_function,
    api_key: None | str = None,
):
    """
    Fetches and parses data for a list of companies.

    Args:
        companies (list[str]): A list of company names.
        fetch_function (str): The name of the function used to fetch data for a single company.
        parse_function: The function used to parse the fetched data.
        api_key (None | str, optional): An API key for accessing data. Defaults to None.

    Returns:
        tuple: A tuple containing two elements:
            - A pandas DataFrame containing the parsed data for all companies.
            - A list of companies that were not successfully parsed.

    """

    parsed_data = []
    companies_copy = copy.deepcopy(companies)

    for company in companies:
        parsed = single_pull_and_parse(
            company, fetch_function, parse_function, api_key=api_key
        )

        if parsed is not None:
            parsed_data.append(parsed)
            companies_copy.remove(company)
            print(f"{company} done and removed from list")

    return pd.concat(parsed_data), companies_copy

# %%
income_statement_data, failed_companies = pull_and_parse(
    top_companies[:2], "INCOME_STATEMENT", parse_income_statement, api_key=api_key
)
# Out:
# AAPL done and removed from list
# MSFT done and removed from list

# %%
income_statement_data
# Out:
#    symbol report_type       date  gross_profit  total_revenue  \
# 0    AAPL      annual 2023-09-30  1.691480e+11   3.793520e+11
# 1    AAPL      annual 2022-09-30  1.707820e+11   3.913970e+11
# 2    AAPL      annual 2021-09-30  1.528360e+11   3.631720e+11
# 3    AAPL      annual 2020-09-30  1.049560e+11   2.716420e+11
# 4    AAPL      annual 2019-09-30  9.839200e+10   2.565980e+11
# ..    ...         ...        ...           ...            ...
# 61   MSFT   quarterly 2008-09-30  1.221300e+10   1.506100e+10
# 62   MSFT   quarterly 2008-06-30  1.297100e+10   1.583700e+10
# 63   MSFT   quarterly 2008-03-31  1.194000e+10   1.445400e+10
# 64   MSFT   quarterly 2007-12-31  1.282400e+10   1.636700e+10
# 65   MSFT   quarterly 2007-09-30  1.108700e+10   1.376200e+10
#
#     cost_of_revenue          cogs  operating_income  net_investment_income  \
# 0      2.390690e+11  2.141370e+11      1.143010e+11           3.750000e+09
# 1      2.486400e+11  2.235460e+11      1.194370e+11           2.825000e+09
# 2      2.349540e+11  2.129810e+11      1.089490e+11           2.843000e+09
# 3      1.894750e+11  1.695590e+11      6.628800e+10           3.763000e+09
# 4      1.800270e+11  1.617820e+11      6.393000e+10           4.961000e+09
# ..              ...           ...               ...                    ...
# 61     2.848000e+09  2.848000e+09      5.999000e+09                    NaN
# 62     2.866000e+09  2.866000e+09      5.684000e+09                    NaN
# 63     2.514000e+09  2.514000e+09      4.409000e+09                    NaN
# 64     3.543000e+09  3.543000e+09      6.481000e+09                    NaN
# 65     2.675000e+09  2.675000e+09      5.918000e+09                    NaN
#
#     net_interest_income  ...  depreciation  depreciation_amortization  \
# 0         -3.933000e+09  ...  8.500000e+09               1.151900e+10
# 1         -2.931000e+09  ...  8.700000e+09               1.110400e+10
# 2         -2.645000e+09  ...  9.500000e+09               1.128400e+10
# 3         -2.873000e+09  ...  9.700000e+09               1.105600e+10
# 4         -3.576000e+09  ...  1.130000e+10               1.254700e+10
# ..                  ...  ...           ...                        ...
# 61                  NaN  ...           NaN               5.850000e+08
# 62                  NaN  ...           NaN               6.080000e+08
# 63                  NaN  ...           NaN               5.320000e+08
# 64                  NaN  ...           NaN               4.810000e+08
# 65                  NaN  ...           NaN               4.350000e+08
#
#     income_before_tax  income_tax_expense  interest_and_debt_expense  \
# 0        1.137360e+11        1.674100e+10               3.933000e+09
# 1        1.191030e+11        1.930000e+10               2.931000e+09
# 2        1.092070e+11        1.452700e+10               2.645000e+09
# 3        6.709100e+10        9.680000e+09               2.873000e+09
# 4        6.573700e+10        1.048100e+10               3.576000e+09
# ..                ...                 ...                        ...
# 61       5.991000e+09        1.618000e+09                        NaN
# 62       5.968000e+09        1.671000e+09                        NaN
# 63       4.810000e+09        4.220000e+08                        NaN
# 64       6.820000e+09        2.113000e+09                        NaN
# 65       6.216000e+09        1.927000e+09                        NaN
#
#     net_income_from_continuing_operations  comprehensive_income          ebit  \
# 0                            9.699500e+10          9.665200e+10  1.176690e+11
# 1                            9.980300e+10          8.853100e+10  1.220340e+11
# 2                            9.468000e+10          9.524900e+10  1.118520e+11
# 3                            5.741100e+10          5.745300e+10  6.996400e+10
# 4                            5.525600e+10          5.803700e+10  6.931300e+10
# ..                                    ...                   ...           ...
# 61                                    NaN                   NaN  5.999000e+09
# 62                                    NaN                   NaN  5.617000e+09
# 63                                    NaN                   NaN  4.234000e+09
# 64                                    NaN                   NaN  6.348000e+09
# 65                                    NaN                   NaN  5.859000e+09
#
#           ebitda    net_income
# 0   1.258200e+11  9.699500e+10
# 1   1.305410e+11  9.980300e+10
# 2   1.202330e+11  9.468000e+10
# 3   7.734400e+10  5.741100e+10
# 4   7.647700e+10  5.525600e+10
# ..           ...           ...
# 61  6.799000e+09  4.373000e+09
# 62  6.225000e+09  4.297000e+09
# 63  4.766000e+09  4.388000e+09
# 64  6.829000e+09  4.707000e+09
# 65  6.294000e+09  4.289000e+09
#
# [158 rows x 24 columns]

# %%
income_statement_data.dtypes
# Out:
# symbol                                           object
# report_type                                      object
# date                                     datetime64[ns]
# gross_profit                                    float64
# total_revenue                                   float64
# cost_of_revenue                                 float64
# cogs                                            float64
# operating_income                                float64
# net_investment_income                           float64
# net_interest_income                             float64
# interest_income                                 float64
# interest_expense                                float64
# non_interest_income                             float64
# other_non_operating_income                      float64
# depreciation                                    float64
# depreciation_amortization                       float64
# income_before_tax                               float64
# income_tax_expense                              float64
# interest_and_debt_expense                       float64
# net_income_from_continuing_operations           float64
# comprehensive_income                            float64
# ebit                                            float64
# ebitda                                          float64
# net_income                                      float64
# dtype: object

# %%
failed_companies
# Out:
# []

# %%
# income_statement_data_list = []
# for company in top_companies[:7]:
#     single_income_statement_data = single_pull_and_parse(
#         company,
#         'INCOME_STATEMENT',
#         parse_income_statement,
#         api_key=api_key,
#     )
#     income_statement_data_list.append(single_income_statement_data)
# Out:
# AAPL data fetch succeeded
# AAPL data parsing succeeded
# MSFT data fetch succeeded
# MSFT data parsing succeeded
# AMZN data fetch succeeded
# AMZN data parsing succeeded
# GOOGL data fetch succeeded
# GOOGL data parsing succeeded
# GOOG data fetch succeeded
# GOOG data parsing succeeded
# Rate limit exceeded.  Waiting 60 seconds and trying again.
# META data fetch succeeded
# META data parsing succeeded
# TSLA data fetch succeeded
# TSLA data parsing succeeded

# %%
# ?django.setup
# Out:
# Signature: django.setup(set_prefix=True)
# Docstring:
# Configure the settings (this happens as a side effect of accessing the
# first setting), configure logging and populate the app registry.
# Set the thread-local urlresolvers script prefix if `set_prefix` is True.
# File:      ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/django/__init__.py
# Type:      function

# %%
# income_statement_data = pd.concat(income_statement_data_list)
# income_statement_data.to_csv('data/income_statement_data.csv', index=False)

# %%
top_companies_copy = copy.deepcopy(top_companies)
for company in top_companies:
    try:
        data = parse_alpha_vantage.fetch_data(
            company, function="TIME_SERIES_MONTHLY_ADJUSTED", api_key=api_key
        )
        print(f"{company} data fetch succeeded")
        parsed_data.append(parse_alpha_vantage.parse_monthly_adjusted(data))
        print(f"{company} data parsing and appending succeeded")
        top_companies_copy.remove(company)
        print(f"{company} done and removed from list")
    except KeyError:
        print(f"{company} had problem")

top_companies = copy.deepcopy(top_companies_copy)
# Out:
# AAPL

# %%
# company_prices = pd.concat(parsed_data)
# company_prices = company_prices.drop_duplicates(['symbol', 'date'])
# company_prices.to_csv('data/monthly_top50_company_prices.csv', index=False)
# company_prices

# %%
# Replace these with your details
username = "briedle"
hostname = "localhost"  # or your server IP address/hostname
database_name = "financial"

engine = sqlalchemy.create_engine(
    f"postgresql://{username}:{password}@{hostname}/{database_name}"
)
engine

income_statement_data.to_sql(
    "stocks_incomestatementdata", engine, if_exists="append", index=False
)
# Out:
# Engine(postgresql://briedle:***@localhost/financial)

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2119, in Connection._exec_insertmany_context(self, dialect, context)
#    2118     else:
# -> 2119         dialect.do_execute(
#    2120             cursor,
#    2121             sub_stmt,
#    2122             sub_params,
#    2123             context,
#    2124         )
#    2126 except BaseException as e:
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# InvalidTextRepresentation: invalid input syntax for type numeric: "None"
# LINE 1: ...0000', '-1456000000', '3999000000', '1456000000', 'None', '-...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 income_statement_data.to_sql('stocks_incomestatementdata', engine, if_exists='append', index=False)
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/core/generic.py:3084, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3080 [(1,), (None,), (2,)]
#    3081 """  # noqa: E501
#    3082 from pandas.io import sql
# -> 3084 return sql.to_sql(
#    3085     self,
#    3086     name,
#    3087     con,
#    3088     schema=schema,
#    3089     if_exists=if_exists,
#    3090     index=index,
#    3091     index_label=index_label,
#    3092     chunksize=chunksize,
#    3093     dtype=dtype,
#    3094     method=method,
#    3095 )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/pandas/io/sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1419     raise exc.ObjectNotExecutableError(statement) from err
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:514, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     512     if TYPE_CHECKING:
#     513         assert isinstance(self, Executable)
# --> 514     return connection._execute_clauseelement(
#     515         self, distilled_params, execution_options
#     516     )
#     517 else:
#     518     raise exc.ObjectNotExecutableError(self)
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1632     "compiled_cache", self.engine._compiled_cache
#    1633 )
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)
#    1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#    1656     self.dispatch.after_execute(
#    1657         self,
#    1658         elem,
#    (...)
#    1662         ret,
#    1663     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1847, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844 context.pre_exec()
#    1846 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1847     return self._exec_insertmany_context(dialect, context)
#    1848 else:
#    1849     return self._exec_single_context(
#    1850         dialect, context, statement, parameters
#    1851     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2127, in Connection._exec_insertmany_context(self, dialect, context)
#    2119         dialect.do_execute(
#    2120             cursor,
#    2121             sub_stmt,
#    2122             sub_params,
#    2123             context,
#    2124         )
#    2126 except BaseException as e:
# -> 2127     self._handle_dbapi_exception(
#    2128         e,
#    2129         sql_util._long_statement(sub_stmt),
#    2130         sub_params,
#    2131         cursor,
#    2132         context,
#    2133         is_sub_exec=True,
#    2134     )
#    2136 if engine_events:
#    2137     self.dispatch.after_cursor_execute(
#    2138         self,
#    2139         cursor,
#    (...)
#    2143         context.executemany,
#    2144     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2356, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354 elif should_wrap:
#    2355     assert sqlalchemy_exception is not None
# -> 2356     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2357 else:
#    2358     assert exc_info[1] is not None
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2119, in Connection._exec_insertmany_context(self, dialect, context)
#    2117             break
#    2118     else:
# -> 2119         dialect.do_execute(
#    2120             cursor,
#    2121             sub_stmt,
#    2122             sub_params,
#    2123             context,
#    2124         )
#    2126 except BaseException as e:
#    2127     self._handle_dbapi_exception(
#    2128         e,
#    2129         sql_util._long_statement(sub_stmt),
#    (...)
#    2133         is_sub_exec=True,
#    2134     )
#
# File ~/.local/share/virtualenvs/finance-zPHMDCNI/lib/python3.11/site-packages/sqlalchemy/engine/default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "None"
# LINE 1: ...0000', '-1456000000', '3999000000', '1456000000', 'None', '-...
#                                                              ^
#
# [SQL: INSERT INTO stocks_incomestatementdata (symbol, report_type, date, gross_profit, total_revenue, cost_of_revenue, cogs, operating_income, net_investment_income, net_interest_income, interest_income, interest_expense, non_interest_income, other_non_ope ... 291768 characters truncated ... erations__461)s, %(ebit__461)s, %(ebitda__461)s, %(net_income__461)s, %(comprehensive_income__461)s)]
# [parameters: {'report_type__0': 'annual', 'interest_and_debt_expense__0': '3933000000', 'interest_expense__0': '3933000000', 'net_interest_income__0': '-3933000000', 'date__0': '2023-09-30', 'net_income_from_continuing_operations__0': '96995000000', 'comprehensive_income__0': '96652000000', 'cogs__0': '214137000000', 'income_before_tax__0': '113736000000', 'total_revenue__0': '379352000000', 'interest_income__0': '183000000', 'gross_profit__0': '169148000000', 'net_investment_income__0': '3750000000', 'depreciation__0': '8500000000', 'cost_of_revenue__0': '239069000000', 'net_income__0': '96995000000', 'operating_income__0': '114301000000', 'ebitda__0': '125820000000', 'non_interest_income__0': '383285000000', 'ebit__0': '117669000000', 'income_tax_expense__0': '16741000000', 'depreciation_amortization__0': '11519000000', 'other_non_operating_income__0': '-382000000', 'symbol__0': 'AAPL', 'report_type__1': 'annual', 'interest_and_debt_expense__1': '2931000000', 'interest_expense__1': '2931000000', 'net_interest_income__1': '-2931000000', 'date__1': '2022-09-30', 'net_income_from_continuing_operations__1': '99803000000', 'comprehensive_income__1': '88531000000', 'cogs__1': '223546000000', 'income_before_tax__1': '119103000000', 'total_revenue__1': '391397000000', 'interest_income__1': '106000000', 'gross_profit__1': '170782000000', 'net_investment_income__1': '2825000000', 'depreciation__1': '8700000000', 'cost_of_revenue__1': '248640000000', 'net_income__1': '99803000000', 'operating_income__1': '119437000000', 'ebitda__1': '130541000000', 'non_interest_income__1': '394328000000', 'ebit__1': '122034000000', 'income_tax_expense__1': '19300000000', 'depreciation_amortization__1': '11104000000', 'other_non_operating_income__1': '-228000000', 'symbol__1': 'AAPL', 'report_type__2': 'annual', 'interest_and_debt_expense__2': '2645000000' ... 10988 parameters truncated ... 'other_non_operating_income__459': '3180000', 'symbol__459': 'TSLA', 'report_type__460': 'quarterly', 'interest_and_debt_expense__460': 'None', 'interest_expense__460': '464000', 'net_interest_income__460': 'None', 'date__460': '2010-06-30', 'net_income_from_continuing_operations__460': 'None', 'comprehensive_income__460': 'None', 'cogs__460': '22144000', 'income_before_tax__460': '-38508000', 'total_revenue__460': '28405000', 'interest_income__460': 'None', 'gross_profit__460': '6261000', 'net_investment_income__460': 'None', 'depreciation__460': 'None', 'cost_of_revenue__460': '22144000', 'net_income__460': '-38517000', 'operating_income__460': '-31362000', 'ebitda__460': '-28879000', 'non_interest_income__460': 'None', 'ebit__460': '-38044000', 'income_tax_expense__460': '9000', 'depreciation_amortization__460': '2483000', 'other_non_operating_income__460': '-6729000', 'symbol__460': 'TSLA', 'report_type__461': 'quarterly', 'interest_and_debt_expense__461': 'None', 'interest_expense__461': '230000', 'net_interest_income__461': 'None', 'date__461': '2010-03-31', 'net_income_from_continuing_operations__461': 'None', 'comprehensive_income__461': 'None', 'cogs__461': '16960000', 'income_before_tax__461': '-29401000', 'total_revenue__461': '20812000', 'interest_income__461': 'None', 'gross_profit__461': '3852000', 'net_investment_income__461': 'None', 'depreciation__461': 'None', 'cost_of_revenue__461': '16960000', 'net_income__461': '-29519000', 'operating_income__461': '-25998000', 'ebitda__461': '-23857000', 'non_interest_income__461': 'None', 'ebit__461': '-25998000', 'income_tax_expense__461': '118000', 'depreciation_amortization__461': '2141000', 'other_non_operating_income__461': 'None', 'symbol__461': 'TSLA'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
income_statement_data
# Out:
#    symbol report_type        date  gross_profit total_revenue cost_of_revenue  \
# 0    AAPL      annual  2023-09-30  169148000000  379352000000    239069000000
# 1    AAPL      annual  2022-09-30  170782000000  391397000000    248640000000
# 2    AAPL      annual  2021-09-30  152836000000  363172000000    234954000000
# 3    AAPL      annual  2020-09-30  104956000000  271642000000    189475000000
# 4    AAPL      annual  2019-09-30   98392000000  256598000000    180027000000
# ..    ...         ...         ...           ...           ...             ...
# 61   MSFT   quarterly  2008-09-30   12213000000   15061000000      2848000000
# 62   MSFT   quarterly  2008-06-30   12971000000   15837000000      2866000000
# 63   MSFT   quarterly  2008-03-31   11940000000   14454000000      2514000000
# 64   MSFT   quarterly  2007-12-31   12824000000   16367000000      3543000000
# 65   MSFT   quarterly  2007-09-30   11087000000   13762000000      2675000000
#
#             cogs operating_income net_investment_income net_interest_income  \
# 0   214137000000     114301000000            3750000000         -3933000000
# 1   223546000000     119437000000            2825000000         -2931000000
# 2   212981000000     108949000000            2843000000         -2645000000
# 3   169559000000      66288000000            3763000000         -2873000000
# 4   161782000000      63930000000            4961000000         -3576000000
# ..           ...              ...                   ...                 ...
# 61    2848000000       5999000000                  None                None
# 62    2866000000       5684000000                  None                None
# 63    2514000000       4409000000                  None                None
# 64    3543000000       6481000000                  None                None
# 65    2675000000       5918000000                  None                None
#
#     ... depreciation depreciation_amortization income_before_tax  \
# 0   ...   8500000000               11519000000      113736000000
# 1   ...   8700000000               11104000000      119103000000
# 2   ...   9500000000               11284000000      109207000000
# 3   ...   9700000000               11056000000       67091000000
# 4   ...  11300000000               12547000000       65737000000
# ..  ...          ...                       ...               ...
# 61  ...         None                 585000000        5991000000
# 62  ...         None                 608000000        5968000000
# 63  ...         None                 532000000        4810000000
# 64  ...         None                 481000000        6820000000
# 65  ...         None                 435000000        6216000000
#
#    income_tax_expense interest_and_debt_expense  \
# 0         16741000000                3933000000
# 1         19300000000                2931000000
# 2         14527000000                2645000000
# 3          9680000000                2873000000
# 4         10481000000                3576000000
# ..                ...                       ...
# 61         1618000000                      None
# 62         1671000000                      None
# 63          422000000                      None
# 64         2113000000                      None
# 65         1927000000                      None
#
#    net_income_from_continuing_operations comprehensive_income          ebit  \
# 0                            96995000000          96652000000  117669000000
# 1                            99803000000          88531000000  122034000000
# 2                            94680000000          95249000000  111852000000
# 3                            57411000000          57453000000   69964000000
# 4                            55256000000          58037000000   69313000000
# ..                                   ...                  ...           ...
# 61                                  None                 None    5999000000
# 62                                  None                 None    5617000000
# 63                                  None                 None    4234000000
# 64                                  None                 None    6348000000
# 65                                  None                 None    5859000000
#
#           ebitda   net_income
# 0   125820000000  96995000000
# 1   130541000000  99803000000
# 2   120233000000  94680000000
# 3    77344000000  57411000000
# 4    76477000000  55256000000
# ..           ...          ...
# 61    6799000000   4373000000
# 62    6225000000   4297000000
# 63    4766000000   4388000000
# 64    6829000000   4707000000
# 65    6294000000   4289000000
#
# [158 rows x 24 columns]

# %%
income_statement_data.dtypes
# Out:
# symbol                                   object
# report_type                              object
# date                                     object
# gross_profit                             object
# total_revenue                            object
# cost_of_revenue                          object
# cogs                                     object
# operating_income                         object
# net_investment_income                    object
# net_interest_income                      object
# interest_income                          object
# interest_expense                         object
# non_interest_income                      object
# other_non_operating_income               object
# depreciation                             object
# depreciation_amortization                object
# income_before_tax                        object
# income_tax_expense                       object
# interest_and_debt_expense                object
# net_income_from_continuing_operations    object
# comprehensive_income                     object
# ebit                                     object
# ebitda                                   object
# net_income                               object
# dtype: object

# %%
def str_none_to_none(value):
    if value in ["None", "none", ""]:
        return None
    else:
        return value


for col in income_statement_data.columns:
    if col in ("symbol", "report_type"):
        income_statement_data[col] = income_statement_data[col].astype("str")
    elif col == "date":
        income_statement_data[col] = pd.to_datetime(income_statement_data[col])
    else:
        income_statement_data[col] = income_statement_data[col].apply(str_none_to_none)
        income_statement_data[col] = income_statement_data[col].astype("float")

# %%
income_statement_data
# Out:
#    symbol report_type       date  gross_profit  total_revenue  \
# 0    AAPL      annual 2023-09-30  1.691480e+11   3.793520e+11
# 1    AAPL      annual 2022-09-30  1.707820e+11   3.913970e+11
# 2    AAPL      annual 2021-09-30  1.528360e+11   3.631720e+11
# 3    AAPL      annual 2020-09-30  1.049560e+11   2.716420e+11
# 4    AAPL      annual 2019-09-30  9.839200e+10   2.565980e+11
# ..    ...         ...        ...           ...            ...
# 61   MSFT   quarterly 2008-09-30  1.221300e+10   1.506100e+10
# 62   MSFT   quarterly 2008-06-30  1.297100e+10   1.583700e+10
# 63   MSFT   quarterly 2008-03-31  1.194000e+10   1.445400e+10
# 64   MSFT   quarterly 2007-12-31  1.282400e+10   1.636700e+10
# 65   MSFT   quarterly 2007-09-30  1.108700e+10   1.376200e+10
#
#     cost_of_revenue          cogs  operating_income  net_investment_income  \
# 0      2.390690e+11  2.141370e+11      1.143010e+11           3.750000e+09
# 1      2.486400e+11  2.235460e+11      1.194370e+11           2.825000e+09
# 2      2.349540e+11  2.129810e+11      1.089490e+11           2.843000e+09
# 3      1.894750e+11  1.695590e+11      6.628800e+10           3.763000e+09
# 4      1.800270e+11  1.617820e+11      6.393000e+10           4.961000e+09
# ..              ...           ...               ...                    ...
# 61     2.848000e+09  2.848000e+09      5.999000e+09                    NaN
# 62     2.866000e+09  2.866000e+09      5.684000e+09                    NaN
# 63     2.514000e+09  2.514000e+09      4.409000e+09                    NaN
# 64     3.543000e+09  3.543000e+09      6.481000e+09                    NaN
# 65     2.675000e+09  2.675000e+09      5.918000e+09                    NaN
#
#     net_interest_income  ...  depreciation  depreciation_amortization  \
# 0         -3.933000e+09  ...  8.500000e+09               1.151900e+10
# 1         -2.931000e+09  ...  8.700000e+09               1.110400e+10
# 2         -2.645000e+09  ...  9.500000e+09               1.128400e+10
# 3         -2.873000e+09  ...  9.700000e+09               1.105600e+10
# 4         -3.576000e+09  ...  1.130000e+10               1.254700e+10
# ..                  ...  ...           ...                        ...
# 61                  NaN  ...           NaN               5.850000e+08
# 62                  NaN  ...           NaN               6.080000e+08
# 63                  NaN  ...           NaN               5.320000e+08
# 64                  NaN  ...           NaN               4.810000e+08
# 65                  NaN  ...           NaN               4.350000e+08
#
#     income_before_tax  income_tax_expense  interest_and_debt_expense  \
# 0        1.137360e+11        1.674100e+10               3.933000e+09
# 1        1.191030e+11        1.930000e+10               2.931000e+09
# 2        1.092070e+11        1.452700e+10               2.645000e+09
# 3        6.709100e+10        9.680000e+09               2.873000e+09
# 4        6.573700e+10        1.048100e+10               3.576000e+09
# ..                ...                 ...                        ...
# 61       5.991000e+09        1.618000e+09                        NaN
# 62       5.968000e+09        1.671000e+09                        NaN
# 63       4.810000e+09        4.220000e+08                        NaN
# 64       6.820000e+09        2.113000e+09                        NaN
# 65       6.216000e+09        1.927000e+09                        NaN
#
#     net_income_from_continuing_operations  comprehensive_income          ebit  \
# 0                            9.699500e+10          9.665200e+10  1.176690e+11
# 1                            9.980300e+10          8.853100e+10  1.220340e+11
# 2                            9.468000e+10          9.524900e+10  1.118520e+11
# 3                            5.741100e+10          5.745300e+10  6.996400e+10
# 4                            5.525600e+10          5.803700e+10  6.931300e+10
# ..                                    ...                   ...           ...
# 61                                    NaN                   NaN  5.999000e+09
# 62                                    NaN                   NaN  5.617000e+09
# 63                                    NaN                   NaN  4.234000e+09
# 64                                    NaN                   NaN  6.348000e+09
# 65                                    NaN                   NaN  5.859000e+09
#
#           ebitda    net_income
# 0   1.258200e+11  9.699500e+10
# 1   1.305410e+11  9.980300e+10
# 2   1.202330e+11  9.468000e+10
# 3   7.734400e+10  5.741100e+10
# 4   7.647700e+10  5.525600e+10
# ..           ...           ...
# 61  6.799000e+09  4.373000e+09
# 62  6.225000e+09  4.297000e+09
# 63  4.766000e+09  4.388000e+09
# 64  6.829000e+09  4.707000e+09
# 65  6.294000e+09  4.289000e+09
#
# [158 rows x 24 columns]

# %%
income_statement_data.to_sql(
    "stocks_incomestatementdata", engine, if_exists="append", index=False
)
# Out:
# 158

# %%
# Let's see if we can get a list of available stock tickers
t = pav.fetch_data(
    stock_symbol="", function="SYMBOL_SEARCH", api_key=api_key, keywords="a"
)

t
# Out:
# {'bestMatches': [{'1. symbol': 'A',
#    '2. name': 'Agilent Technologies Inc',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'A02.FRK',
#    '2. name': 'Adways Inc',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A04.FRK',
#    '2. name': 'Ascential plc',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A07.FRK',
#    '2. name': 'AVANCE GAS HLDG DL 2',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A0H.FRK',
#    '2. name': 'AUXICO RESOURCES CANADA',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A0P.FRK',
#    '2. name': 'ARCTIC PAPER SA ZY 1',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A0T.FRK',
#    '2. name': 'American Tower Corp',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A0U.FRK',
#    '2. name': 'AZINCOURT URANIUM',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.3333'},
#   {'1. symbol': 'A0B0.FRK',
#    '2. name': 'AMALGAMATED FIN. DL-01',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.2857'},
#   {'1. symbol': 'A0I0.FRK',
#    '2. name': 'APPIA RARE EARTH+U O.N.',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.2857'}]}

# %%
# Get S&P 500 tickers
sp500_tickers = yf.Tickers("^GSPC")

# Fetch data (this will take some time depending on your internet connection)
# The information fetched may not directly provide company names, requiring additional processing

# You would typically iterate over `sp500_tickers` to build a comprehensive DataFrame

# %%
cursor.execute()

# %%
rows = cursor.fetchall()
rows
# Out:
# [('ZTS',),
#  ('ZBRA',),
#  ('ZBH',),
#  ('YUM',),
#  ('XYL',),
#  ('XRAY',),
#  ('XOM',),
#  ('XEL',),
#  ('WYNN',),
#  ('WY',),
#  ('WTW',),
#  ('WST',),
#  ('WRK',),
#  ('WRB',),
#  ('WMT',),
#  ('WMB',),
#  ('WM',),
#  ('WFC',),
#  ('WELL',),
#  ('WEC',),
#  ('WDC',),
#  ('WBD',),
#  ('WBA',),
#  ('WAT',),
#  ('WAB',),
#  ('VZ',),
#  ('VTRS',),
#  ('VTR',),
#  ('VRTX',),
#  ('VRSN',),
#  ('VRSK',),
#  ('VMC',),
#  ('VLTO',),
#  ('VLO',),
#  ('VICI',),
#  ('VFC',),
#  ('V',),
#  ('USB',),
#  ('URI',),
#  ('UPS',),
#  ('UNP',),
#  ('UNH',),
#  ('ULTA',),
#  ('UHS',),
#  ('UDR',),
#  ('UBER',),
#  ('UAL',),
#  ('TYL',),
#  ('TXT',),
#  ('TXN',),
#  ('TTWO',),
#  ('TT',),
#  ('TSN',),
#  ('TSLA',),
#  ('TSCO',),
#  ('TRV',),
#  ('TROW',),
#  ('TRMB',),
#  ('TRGP',),
#  ('TPR',),
#  ('TMUS',),
#  ('TMO',),
#  ('TJX',),
#  ('TGT',),
#  ('TFX',),
#  ('TFC',),
#  ('TER',),
#  ('TEL',),
#  ('TECH',),
#  ('TDY',),
#  ('TDG',),
#  ('TAP',),
#  ('T',),
#  ('SYY',),
#  ('SYK',),
#  ('SYF',),
#  ('SWKS',),
#  ('SWK',),
#  ('STZ',),
#  ('STX',),
#  ('STT',),
#  ('STLD',),
#  ('STE',),
#  ('SRE',),
#  ('SPGI',),
#  ('SPG',),
#  ('SO',),
#  ('SNPS',),
#  ('SNA',),
#  ('SMCI',),
#  ('SLB',),
#  ('SJM',),
#  ('SHW',),
#  ('SCHW',),
#  ('SBUX',),
#  ('SBAC',),
#  ('RVTY',),
#  ('RTX',),
#  ('RSG',),
#  ('ROST',)]

# %%
def create_db_engine(
    db_name: str, 
    db_user: str = 'briedle', 
    db_password: str = 'ben21788', 
    db_host: str = 'localhost', 
    db_port: str = '5432',
):
    """
    Creates a database engine for connecting to a PostgreSQL database.

    Args:
        db_name (str): The name of the database.
        db_user (str): The username for the database.
        db_password (str): The password for the database.
        db_host (str): The host for the database.
        db_port (str): The port for the database.

    Returns:
        sqlalchemy.engine.base.Engine: A database engine object.
    """
    engine = sqlalchemy.create_engine(
        f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
    )
    return engine

# %%
engine = create_db_engine('financial')

query = 'select symbol from stocks_basestockdata order by symbol desc limit 100'

top_100 = pd.read_sql_query(query, engine)
top_100
# Out:
#    symbol
# 0     ZTS
# 1    ZBRA
# 2     ZBH
# 3     YUM
# 4     XYL
# ..    ...
# 95   SBAC
# 96   RVTY
# 97    RTX
# 98    RSG
# 99   ROST
#
# [100 rows x 1 columns]

# %%
inspector = sqlalchemy.inspect(engine)
tables = inspector.get_table_names()
tables
# Out:
# ['django_migrations',
#  'django_content_type',
#  'auth_permission',
#  'auth_group',
#  'auth_group_permissions',
#  'auth_user',
#  'auth_user_groups',
#  'auth_user_user_permissions',
#  'django_admin_log',
#  'django_session',
#  'stocks_monthlystockpricedata',
#  'stocks_incomestatementdata',
#  'stocks_basestockdata']

# %%
income_statement_df = pd.read_sql_table('stocks_incomestatementdata', engine)
income_statement_df
# Out:
#       id report_type       date  gross_profit  total_revenue  cost_of_revenue  \
# 0      1      annual 2023-09-30  1.691480e+11   3.793520e+11     2.390690e+11
# 1      2      annual 2022-09-30  1.707820e+11   3.913970e+11     2.486400e+11
# 2      3      annual 2021-09-30  1.528360e+11   3.631720e+11     2.349540e+11
# 3      4      annual 2020-09-30  1.049560e+11   2.716420e+11     1.894750e+11
# 4      5      annual 2019-09-30  9.839200e+10   2.565980e+11     1.800270e+11
# ..   ...         ...        ...           ...            ...              ...
# 311  312   quarterly 2008-09-30  1.221300e+10   1.506100e+10     2.848000e+09
# 312  313   quarterly 2008-06-30  1.297100e+10   1.583700e+10     2.866000e+09
# 313  314   quarterly 2008-03-31  1.194000e+10   1.445400e+10     2.514000e+09
# 314  315   quarterly 2007-12-31  1.282400e+10   1.636700e+10     3.543000e+09
# 315  316   quarterly 2007-09-30  1.108700e+10   1.376200e+10     2.675000e+09
#
#              cogs  operating_income  net_investment_income  \
# 0    2.141370e+11      1.143010e+11           3.750000e+09
# 1    2.235460e+11      1.194370e+11           2.825000e+09
# 2    2.129810e+11      1.089490e+11           2.843000e+09
# 3    1.695590e+11      6.628800e+10           3.763000e+09
# 4    1.617820e+11      6.393000e+10           4.961000e+09
# ..            ...               ...                    ...
# 311  2.848000e+09      5.999000e+09                    NaN
# 312  2.866000e+09      5.684000e+09                    NaN
# 313  2.514000e+09      4.409000e+09                    NaN
# 314  3.543000e+09      6.481000e+09                    NaN
# 315  2.675000e+09      5.918000e+09                    NaN
#
#      net_interest_income  ...  depreciation_amortization  income_before_tax  \
# 0          -3.933000e+09  ...               1.151900e+10       1.137360e+11
# 1          -2.931000e+09  ...               1.110400e+10       1.191030e+11
# 2          -2.645000e+09  ...               1.128400e+10       1.092070e+11
# 3          -2.873000e+09  ...               1.105600e+10       6.709100e+10
# 4          -3.576000e+09  ...               1.254700e+10       6.573700e+10
# ..                   ...  ...                        ...                ...
# 311                  NaN  ...               5.850000e+08       5.991000e+09
# 312                  NaN  ...               6.080000e+08       5.968000e+09
# 313                  NaN  ...               5.320000e+08       4.810000e+09
# 314                  NaN  ...               4.810000e+08       6.820000e+09
# 315                  NaN  ...               4.350000e+08       6.216000e+09
#
#      income_tax_expense  interest_and_debt_expense  \
# 0          1.674100e+10               3.933000e+09
# 1          1.930000e+10               2.931000e+09
# 2          1.452700e+10               2.645000e+09
# 3          9.680000e+09               2.873000e+09
# 4          1.048100e+10               3.576000e+09
# ..                  ...                        ...
# 311        1.618000e+09                        NaN
# 312        1.671000e+09                        NaN
# 313        4.220000e+08                        NaN
# 314        2.113000e+09                        NaN
# 315        1.927000e+09                        NaN
#
#      net_income_from_continuing_operations  comprehensive_income  \
# 0                             9.699500e+10          9.665200e+10
# 1                             9.980300e+10          8.853100e+10
# 2                             9.468000e+10          9.524900e+10
# 3                             5.741100e+10          5.745300e+10
# 4                             5.525600e+10          5.803700e+10
# ..                                     ...                   ...
# 311                                    NaN                   NaN
# 312                                    NaN                   NaN
# 313                                    NaN                   NaN
# 314                                    NaN                   NaN
# 315                                    NaN                   NaN
#
#              ebit        ebitda    net_income  stock_id
# 0    1.176690e+11  1.258200e+11  9.699500e+10      None
# 1    1.220340e+11  1.305410e+11  9.980300e+10      None
# 2    1.118520e+11  1.202330e+11  9.468000e+10      None
# 3    6.996400e+10  7.734400e+10  5.741100e+10      None
# 4    6.931300e+10  7.647700e+10  5.525600e+10      None
# ..            ...           ...           ...       ...
# 311  5.999000e+09  6.799000e+09  4.373000e+09      None
# 312  5.617000e+09  6.225000e+09  4.297000e+09      None
# 313  4.234000e+09  4.766000e+09  4.388000e+09      None
# 314  6.348000e+09  6.829000e+09  4.707000e+09      None
# 315  5.859000e+09  6.294000e+09  4.289000e+09      None
#
# [316 rows x 25 columns]

# %%
income_statement_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 income_statement_data
#
# NameError: name 'income_statement_data' is not defined

# %%
import pandas as pd
from stocks.models import IncomeStatementData, BaseStockData

# Assuming income_statement_data is your DataFrame
for _, row in income_statement_data.iterrows():
    # Fetch the corresponding BaseStockData instance
    try:
        stock_instance = BaseStockData.objects.get(symbol=row['symbol'])
    except BaseStockData.DoesNotExist:
        # Handle the case where the symbol does not exist
        print(f"No BaseStockData found for symbol: {row['symbol']}")
        continue
    
    # Create and save the new IncomeStatementData instance
    IncomeStatementData.objects.create(
        stock=stock_instance,
        report_type=row['report_type'],
        date=row['date'],
        gross_profit=row['gross_profit'],
        total_revenue=row['total_revenue'],
        cost_of_revenue=row['cost_of_revenue'],
        # ... include other fields as necessary
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 from stocks.models import IncomeStatementData, BaseStockData
#       4 # Assuming income_statement_data is your DataFrame
# ----> 5 for _, row in income_statement_data.iterrows():
#       6     # Fetch the corresponding BaseStockData instance
#       7     try:
#       8         stock_instance = BaseStockData.objects.get(symbol=row['symbol'])
#
# NameError: name 'income_statement_data' is not defined
